# %% [markdown]
# # Jupyter interface of OrthoSLC (1.0.0)
#
# <b>OrthoSLC</b> is a pipline that perfomrs Reciprocal Best Blast Hit (RBBH) + Single Linkage Clustering (or Markov Clustering) to obtain Orthologous Gene Clusters, which assists task like core genome construction (for phylogeny study) or for comparative genomics. <br>
#
# **This interface** is python jupyter based to facilitate customized analysis. However, for datasets with 500 or more genomes, we still recommend using the binary files, which is mainly written in C++, for optimal performance.<br>
#
# It is: <br>
# * <b>independent</b> of relational database management systems (e.g., MySQL)
# * recommend to handle less prokaryotic genomes.
#
# It is recommended for sub-species level single copy core genome construction since RBBH may not work well for missions like Human-Microbe core genome construction.
#
# <b>Caveat:</b><br>
# The pipeline is currently only tested on Ubuntu 20.04 and 18.04 and Debian strech.
#
# <b>Requirement:</b><br>
# Python3 (suggest newest stable release or higher),<br>
# NCBI Blast+ (suggest 2.12 or higher) <br>
#
# <b>Note:</b><br>
# For all steps, users do not need to make the ourput directory manually, program will do that for you.
#
# Bug report:
# * <jingjie.chencharly@gmail.com>

# %%
import os,sys
import random
import copy
# import numpy as np
# import pandas as pd

from multiprocessing import Lock, Process, Manager
import subprocess
import shutil
from copy import deepcopy

# pip install biopython
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from math import log10

from collections import defaultdict

import time
from typing import List

# def mission spliter
def mission_spliter(lst: List, # a list with largest or most difficult at the first
                    num_splits: int) -> List[List]:
    n = len(lst)
    if num_splits > n:
        num_splits = n

    # Create an empty list of lists to hold the results
    result = [[] for _ in range(num_splits)]

    # Distribute tasks using a round-robin approach
    for i, task in enumerate(lst):
        index = i % num_splits
        result[index].append(task)

    # remove empty task
    result = [sub_list for sub_list in result if sub_list]

    return result

# %% [markdown]
# # Step 1 Genome information preparation

# %% [markdown]
# The pipeline starts with annotated genomes in fasta format. FASTA file name require strain name and extension (e.g., `strain_A.ffn`, `strain_B.fna`, `strain_C.fasta` etc.).<br>
# Step 1 needs the **path to directory of annotated FASTA files** as input, to genereate a header less, tab separated table, in which the
# * first column is a short ID,
# * second column is the strain name,
# * third column as the absolute path.
#
# The short ID of each genome is generated to save computational resources and storage space. Since reciprocal BLAST generates a large volume of files (millions to billions of rows if large number of genomes participated), each row contains the names of the query and subject. If the user provides input FASTA file names like:
#
# * `GCA_900627445.1_PFR31F05_genomic.fasta`
# * `GCA_021980615.1_PDT001237823.1_genomic.fasta`
#
# and such file names become part of gene identifier instead of the short ID used in this program, large size of additional storage will be consumed for intermediate files and even more pressure on computing memory for analysis of 1000~ genomes.

# %% [markdown]
# ## Set path
# * Set variable `raw_annotated_dir_path` to the path of directory of annoated FASTA files
# * Set variable `preparation_output_path` to the path of output tab separated files.<br>
# Then run the codes below [Step 1 execution](###step-1-execution)

# %%
# set your own
# directory path of input fastas
raw_annotated_dir_path = './test_inputs/'
# path of output tsv`
preparation_output_path = './test_op/Step1_op.txt'

# %%
os.makedirs("./test_op", exist_ok=True)

# %% [markdown]
# ## Step 1 execution

# %%
start_c = 0

with open(preparation_output_path, 'w') as pre_op:
    for file_naam in os.listdir(raw_annotated_dir_path):
        abs_path = os.path.join(raw_annotated_dir_path,
                                file_naam
                               )
        abs_path = os.path.abspath(abs_path)
        
        strain_naam = os.path.basename(abs_path)
        strain_naam = os.path.splitext(strain_naam)[0]
        
        start_cs = str(start_c)
        if len(start_cs) == 4:
            start_cs = '0' + start_cs
        
        pre_op.write(start_cs
                     + '\t'
                     + strain_naam
                     + '\t'
                     + abs_path
                     + '\n'
                    )
        start_c += 1
        
pre_op.close()

# %% [markdown]
# # Step2 FASTA dereplication

# %% [markdown]
# Step 2 is to remove potential sequence duplication (e.g., copies of tRNA, some cds) within each genome. This dereplication is equivalent to 100% clustering, to obtain single copy.<br>
# Step 2 **requires the tab separated table output by Step 1 as input**, and specifying a directory for dereplicated files.

# %% [markdown]
# ## define functions

# %%
def redundancy_rm_a_file(path_n_id_tup, # abs path of an input fasta
                         rred_folder, # path to 100% clustered result
                         copy_info,
                        ):
    
    in_fasta = SeqIO.parse(path_n_id_tup[0],
                           'fasta'
                          )
    
    strain_naam = os.path.basename(path_n_id_tup[0])
    strain_naam = os.path.splitext(strain_naam)[0]
    
    short_id = path_n_id_tup[1]
    
    added_seq = defaultdict(list)
    to_save = []
    gene_id_c = 0
    
    for SEQ in in_fasta:
        seq_hash = hash(SEQ.seq)
        if seq_hash not in added_seq:
            to_save.append(SeqRecord(seq = SEQ.seq,
                                     id = short_id + '-' + str(gene_id_c),
                                     description = SEQ.description
                                    )
                          )
            gene_id_c += 1
        
        added_seq[seq_hash].append(SEQ.id)

    copy_info.extend([added_seq[i] for i in added_seq if len(added_seq[i]) > 1])
    SeqIO.write(to_save, 
                os.path.join(os.path.abspath(rred_folder), 
                             strain_naam + '.fasta'
                            ),
                'fasta')

def redundancy_rm_files(m_lst,
                        rred_folder_,
                        copy_info_
                       ):
    
    for ab_fp in m_lst:
        redundancy_rm_a_file(ab_fp, # to provide abs path
                             rred_folder_,
                             copy_info_
                            )

# %% [markdown]
# ## Set path
# * Set variable `preparation_output_path` to the path of output tab separated files.
# * Set variable `dereped_dir_path` to the path to directory of dereplicated files.
# * Set variable `process_number` as thread number.<br>
# Then run the codes below [Step 2 execution](###step-2-execution)

# %%
# set your own
# path of output tsv from Step1
preparation_output_path = 'test_op/Step1_op.txt'
# directory path of output
dereped_dir_path = 'test_op/S2_op_dereped'
# path of copy fragement info
copy_info_path = 'test_op/S2_op_copy_info.txt'
# how many jobs to parallel
process_number = 56

# %% [markdown]
# ## Step 2 execution

# %%
print(time.asctime())

if __name__ == "__main__":
    
    # mkdir or not ----
    if os.path.exists(dereped_dir_path):
        pass
    else:
        os.mkdir(dereped_dir_path)
        
    # read short id ----
    strain_short_pth_n_id = []
    
    with open(preparation_output_path, 'r') as pre_op:
        rls = pre_op.readlines()
        
        for l in rls:
            l_ = l.split('\t')
            strain_short_pth_n_id.append((l_[2][0: -1], # key remove \n
                                          l_[0]
                                         )
                                        )
        
    pre_op.close()
    
    mission_lst = mission_spliter(strain_short_pth_n_id, 
                                  process_number
                                 )

    with Manager() as manager:
        copy_info_list = manager.list()
        # mp ----
        jobs = []
        
        for sub_mission_lst in mission_lst:
        
            p = Process(target = redundancy_rm_files,
                        args = (sub_mission_lst, 
                                dereped_dir_path,
                                copy_info_list
                               )
                       )
            p.start()
            jobs.append(p)
    
    
        for z in jobs:
            z.join()

        copy_info_list = list(copy_info_list)
        copy_info_list = ['\t'.join(i)+'\n' for i in copy_info_list]
        with open(copy_info_path, 'w', encoding='utf-8') as file:
            file.writelines(copy_info_list)
        
        
print(time.asctime())
# Out:
# Sat Jul 12 17:24:55 2025
# Sat Jul 12 17:24:56 2025

# %% [markdown]
# ## <font color="red">Note before next step</font>
# After dereplication, users should give a careful check of <b>size</b> of dereplicated fasta files. It is worth noting that if a fasta file with a very low amount of sequences, getting processed together with all the rest, the final "core" clusters will be heavily affected and may bias your analysis.
#
# Since the core genome construction is similar with intersection construction. <font color="red"><b>It is recommend to remove some very small dereplicated fasta files BEFORE NEXT STEP</b>, e.g., remove all dereplicated <i>E.coli </i> genomes with file size lower than 2.5MB as most should be larger than 4.0MB.</font>

# %%
# !grep -c ">" test_op/S2_op_dereped/* | sort -t: -k2rn
# Out:
# test_op/S2_op_dereped/AMC_707.fasta:7713
# test_op/S2_op_dereped/AMC_487.fasta:5559
# test_op/S2_op_dereped/AMC_596.fasta:5492
# test_op/S2_op_dereped/AMC_56.fasta:5397
# test_op/S2_op_dereped/AMC_615.fasta:5343
# test_op/S2_op_dereped/AMC_473.fasta:5290
# test_op/S2_op_dereped/AMC_539.fasta:5279
# test_op/S2_op_dereped/AMC_772.fasta:5264
# test_op/S2_op_dereped/AMC_263.fasta:5260
# test_op/S2_op_dereped/AMC_837.fasta:5250
# test_op/S2_op_dereped/AMC_515.fasta:5249
# test_op/S2_op_dereped/AMC_796.fasta:5244
# test_op/S2_op_dereped/AMC_285.fasta:5240
# test_op/S2_op_dereped/AMC_930.fasta:5240
# test_op/S2_op_dereped/AMC_556.fasta:5227
# test_op/S2_op_dereped/AMC_301.fasta:5225
# test_op/S2_op_dereped/AMC_159.fasta:5205
# test_op/S2_op_dereped/AMC_81.fasta:5203
# test_op/S2_op_dereped/AMC_441.fasta:5199
# test_op/S2_op_dereped/AMC_61.fasta:5195
# test_op/S2_op_dereped/AMC_299.fasta:5191
# test_op/S2_op_dereped/AMC_220.fasta:5190
# test_op/S2_op_dereped/AMC_450.fasta:5190
# test_op/S2_op_dereped/AMC_869.fasta:5189
# test_op/S2_op_dereped/AMC_651.fasta:5186
# test_op/S2_op_dereped/AMC_334.fasta:5184
# test_op/S2_op_dereped/AMC_351.fasta:5179
# test_op/S2_op_dereped/AMC_444.fasta:5173
# test_op/S2_op_dereped/AMC_174.fasta:5170
# test_op/S2_op_dereped/AMC_395.fasta:5167
# test_op/S2_op_dereped/AMC_514.fasta:5167
# test_op/S2_op_dereped/AMC_148.fasta:5165
# test_op/S2_op_dereped/AMC_164.fasta:5163
# test_op/S2_op_dereped/AMC_3.fasta:5163
# test_op/S2_op_dereped/AMC_85.fasta:5163
# test_op/S2_op_dereped/AMC_485.fasta:5155
# test_op/S2_op_dereped/AMC_789.fasta:5155
# test_op/S2_op_dereped/AMC_330.fasta:5154
# test_op/S2_op_dereped/AMC_229.fasta:5153
# test_op/S2_op_dereped/AMC_938.fasta:5153
# test_op/S2_op_dereped/AMC_939.fasta:5147
# test_op/S2_op_dereped/AMC_342.fasta:5146
# test_op/S2_op_dereped/AMC_227.fasta:5140
# test_op/S2_op_dereped/AMC_844.fasta:5139
# test_op/S2_op_dereped/AMC_179.fasta:5138
# test_op/S2_op_dereped/AMC_400.fasta:5138
# test_op/S2_op_dereped/AMC_762.fasta:5138
# test_op/S2_op_dereped/AMC_902.fasta:5137
# test_op/S2_op_dereped/AMC_882.fasta:5133
# test_op/S2_op_dereped/AMC_9.fasta:5132
# test_op/S2_op_dereped/AMC_340.fasta:5130
# test_op/S2_op_dereped/AMC_758.fasta:5128
# test_op/S2_op_dereped/AMC_490.fasta:5127
# test_op/S2_op_dereped/AMC_462.fasta:5120
# test_op/S2_op_dereped/AMC_903.fasta:5120
# test_op/S2_op_dereped/AMC_782.fasta:5116
# test_op/S2_op_dereped/AMC_97.fasta:5116
# test_op/S2_op_dereped/AMC_476.fasta:5114
# test_op/S2_op_dereped/AMC_664.fasta:5110
# test_op/S2_op_dereped/AMC_172.fasta:5108
# test_op/S2_op_dereped/AMC_5.fasta:5108
# test_op/S2_op_dereped/AMC_650.fasta:5108
# test_op/S2_op_dereped/AMC_112.fasta:5107
# test_op/S2_op_dereped/AMC_558.fasta:5106
# test_op/S2_op_dereped/AMC_884.fasta:5106
# test_op/S2_op_dereped/AMC_241.fasta:5104
# test_op/S2_op_dereped/AMC_621.fasta:5098
# test_op/S2_op_dereped/AMC_975.fasta:5098
# test_op/S2_op_dereped/AMC_578.fasta:5097
# test_op/S2_op_dereped/AMC_465.fasta:5096
# test_op/S2_op_dereped/AMC_180.fasta:5093
# test_op/S2_op_dereped/AMC_628.fasta:5091
# test_op/S2_op_dereped/AMC_759.fasta:5091
# test_op/S2_op_dereped/AMC_316.fasta:5090
# test_op/S2_op_dereped/AMC_769.fasta:5089
# test_op/S2_op_dereped/AMC_967.fasta:5088
# test_op/S2_op_dereped/AMC_193.fasta:5087
# test_op/S2_op_dereped/AMC_258.fasta:5086
# test_op/S2_op_dereped/AMC_629.fasta:5086
# test_op/S2_op_dereped/AMC_375.fasta:5084
# test_op/S2_op_dereped/AMC_751.fasta:5082
# test_op/S2_op_dereped/AMC_763.fasta:5082
# test_op/S2_op_dereped/AMC_90.fasta:5081
# test_op/S2_op_dereped/AMC_65.fasta:5079
# test_op/S2_op_dereped/AMC_812.fasta:5079
# test_op/S2_op_dereped/AMC_866.fasta:5078
# test_op/S2_op_dereped/AMC_585.fasta:5077
# test_op/S2_op_dereped/AMC_781.fasta:5077
# test_op/S2_op_dereped/AMC_779.fasta:5076
# test_op/S2_op_dereped/AMC_226.fasta:5074
# test_op/S2_op_dereped/AMC_231.fasta:5073
# test_op/S2_op_dereped/AMC_604.fasta:5073
# test_op/S2_op_dereped/AMC_332.fasta:5072
# test_op/S2_op_dereped/AMC_666.fasta:5072
# test_op/S2_op_dereped/AMC_198.fasta:5071
# test_op/S2_op_dereped/AMC_894.fasta:5071
# test_op/S2_op_dereped/AMC_207.fasta:5067
# test_op/S2_op_dereped/AMC_614.fasta:5067
# test_op/S2_op_dereped/AMC_931.fasta:5067
# test_op/S2_op_dereped/AMC_352.fasta:5063
# test_op/S2_op_dereped/AMC_83.fasta:5062
# test_op/S2_op_dereped/AMC_318.fasta:5061
# test_op/S2_op_dereped/AMC_431.fasta:5061
# test_op/S2_op_dereped/AMC_847.fasta:5060
# test_op/S2_op_dereped/AMC_749.fasta:5057
# test_op/S2_op_dereped/AMC_544.fasta:5056
# test_op/S2_op_dereped/AMC_277.fasta:5055
# test_op/S2_op_dereped/AMC_670.fasta:5055
# test_op/S2_op_dereped/AMC_923.fasta:5055
# test_op/S2_op_dereped/AMC_223.fasta:5054
# test_op/S2_op_dereped/AMC_675.fasta:5054
# test_op/S2_op_dereped/AMC_84.fasta:5051
# test_op/S2_op_dereped/AMC_177.fasta:5049
# test_op/S2_op_dereped/AMC_673.fasta:5049
# test_op/S2_op_dereped/AMC_739.fasta:5048
# test_op/S2_op_dereped/AMC_690.fasta:5047
# test_op/S2_op_dereped/AMC_874.fasta:5047
# test_op/S2_op_dereped/AMC_649.fasta:5046
# test_op/S2_op_dereped/AMC_121.fasta:5043
# test_op/S2_op_dereped/AMC_201.fasta:5043
# test_op/S2_op_dereped/AMC_498.fasta:5040
# test_op/S2_op_dereped/AMC_569.fasta:5040
# test_op/S2_op_dereped/AMC_442.fasta:5038
# test_op/S2_op_dereped/AMC_854.fasta:5038
# test_op/S2_op_dereped/AMC_969.fasta:5038
# test_op/S2_op_dereped/AMC_602.fasta:5035
# test_op/S2_op_dereped/AMC_833.fasta:5034
# test_op/S2_op_dereped/AMC_120.fasta:5032
# test_op/S2_op_dereped/AMC_609.fasta:5032
# test_op/S2_op_dereped/AMC_890.fasta:5032
# test_op/S2_op_dereped/AMC_643.fasta:5031
# test_op/S2_op_dereped/AMC_19.fasta:5030
# test_op/S2_op_dereped/AMC_359.fasta:5029
# test_op/S2_op_dereped/AMC_493.fasta:5029
# test_op/S2_op_dereped/AMC_199.fasta:5027
# test_op/S2_op_dereped/AMC_292.fasta:5027
# test_op/S2_op_dereped/AMC_586.fasta:5026
# test_op/S2_op_dereped/AMC_66.fasta:5024
# test_op/S2_op_dereped/AMC_158.fasta:5023
# test_op/S2_op_dereped/AMC_266.fasta:5023
# test_op/S2_op_dereped/AMC_73.fasta:5023
# test_op/S2_op_dereped/AMC_961.fasta:5023
# test_op/S2_op_dereped/AMC_228.fasta:5022
# test_op/S2_op_dereped/AMC_632.fasta:5022
# test_op/S2_op_dereped/AMC_267.fasta:5019
# test_op/S2_op_dereped/AMC_271.fasta:5018
# test_op/S2_op_dereped/AMC_284.fasta:5018
# test_op/S2_op_dereped/AMC_863.fasta:5018
# test_op/S2_op_dereped/AMC_175.fasta:5016
# test_op/S2_op_dereped/AMC_685.fasta:5016
# test_op/S2_op_dereped/AMC_64.fasta:5015
# test_op/S2_op_dereped/AMC_693.fasta:5015
# test_op/S2_op_dereped/AMC_706.fasta:5015
# test_op/S2_op_dereped/AMC_540.fasta:5014
# test_op/S2_op_dereped/AMC_947.fasta:5014
# test_op/S2_op_dereped/AMC_754.fasta:5013
# test_op/S2_op_dereped/AMC_958.fasta:5013
# test_op/S2_op_dereped/AMC_272.fasta:5012
# test_op/S2_op_dereped/AMC_412.fasta:5012
# test_op/S2_op_dereped/AMC_86.fasta:5012
# test_op/S2_op_dereped/AMC_369.fasta:5011
# test_op/S2_op_dereped/AMC_665.fasta:5011
# test_op/S2_op_dereped/AMC_183.fasta:5010
# test_op/S2_op_dereped/AMC_312.fasta:5010
# test_op/S2_op_dereped/AMC_396.fasta:5010
# test_op/S2_op_dereped/AMC_699.fasta:5008
# test_op/S2_op_dereped/AMC_760.fasta:5008
# test_op/S2_op_dereped/AMC_160.fasta:5007
# test_op/S2_op_dereped/AMC_974.fasta:5007
# test_op/S2_op_dereped/AMC_113.fasta:5006
# test_op/S2_op_dereped/AMC_161.fasta:5006
# test_op/S2_op_dereped/AMC_386.fasta:5006
# test_op/S2_op_dereped/AMC_956.fasta:5006
# test_op/S2_op_dereped/AMC_622.fasta:5005
# test_op/S2_op_dereped/AMC_44.fasta:5004
# test_op/S2_op_dereped/AMC_799.fasta:5003
# test_op/S2_op_dereped/AMC_892.fasta:5003
# test_op/S2_op_dereped/AMC_588.fasta:5002
# test_op/S2_op_dereped/AMC_646.fasta:5002
# test_op/S2_op_dereped/AMC_99.fasta:5002
# test_op/S2_op_dereped/AMC_130.fasta:5000
# test_op/S2_op_dereped/AMC_410.fasta:5000
# test_op/S2_op_dereped/AMC_219.fasta:4999
# test_op/S2_op_dereped/AMC_429.fasta:4999
# test_op/S2_op_dereped/AMC_640.fasta:4999
# test_op/S2_op_dereped/AMC_741.fasta:4999
# test_op/S2_op_dereped/AMC_964.fasta:4999
# test_op/S2_op_dereped/AMC_204.fasta:4998
# test_op/S2_op_dereped/AMC_815.fasta:4998
# test_op/S2_op_dereped/AMC_39.fasta:4997
# test_op/S2_op_dereped/AMC_661.fasta:4997
# test_op/S2_op_dereped/AMC_568.fasta:4996
# test_op/S2_op_dereped/AMC_952.fasta:4996
# test_op/S2_op_dereped/AMC_492.fasta:4995
# test_op/S2_op_dereped/AMC_553.fasta:4995
# test_op/S2_op_dereped/AMC_688.fasta:4995
# test_op/S2_op_dereped/AMC_701.fasta:4995
# test_op/S2_op_dereped/AMC_42.fasta:4994
# test_op/S2_op_dereped/AMC_669.fasta:4994
# test_op/S2_op_dereped/AMC_948.fasta:4994
# test_op/S2_op_dereped/AMC_104.fasta:4993
# test_op/S2_op_dereped/AMC_151.fasta:4993
# test_op/S2_op_dereped/AMC_641.fasta:4993
# test_op/S2_op_dereped/AMC_75.fasta:4993
# test_op/S2_op_dereped/AMC_564.fasta:4992
# test_op/S2_op_dereped/AMC_667.fasta:4992
# test_op/S2_op_dereped/AMC_686.fasta:4992
# test_op/S2_op_dereped/AMC_816.fasta:4991
# test_op/S2_op_dereped/AMC_926.fasta:4991
# test_op/S2_op_dereped/AMC_217.fasta:4990
# test_op/S2_op_dereped/AMC_393.fasta:4990
# test_op/S2_op_dereped/AMC_482.fasta:4990
# test_op/S2_op_dereped/AMC_971.fasta:4990
# test_op/S2_op_dereped/AMC_499.fasta:4989
# test_op/S2_op_dereped/AMC_436.fasta:4987
# test_op/S2_op_dereped/AMC_852.fasta:4987
# test_op/S2_op_dereped/AMC_364.fasta:4986
# test_op/S2_op_dereped/AMC_676.fasta:4986
# test_op/S2_op_dereped/AMC_82.fasta:4986
# test_op/S2_op_dereped/AMC_380.fasta:4985
# test_op/S2_op_dereped/AMC_94.fasta:4985
# test_op/S2_op_dereped/AMC_872.fasta:4984
# test_op/S2_op_dereped/AMC_420.fasta:4982
# test_op/S2_op_dereped/AMC_526.fasta:4981
# test_op/S2_op_dereped/AMC_587.fasta:4981
# test_op/S2_op_dereped/AMC_133.fasta:4980
# test_op/S2_op_dereped/AMC_590.fasta:4980
# test_op/S2_op_dereped/AMC_155.fasta:4979
# test_op/S2_op_dereped/AMC_915.fasta:4978
# test_op/S2_op_dereped/AMC_48.fasta:4977
# test_op/S2_op_dereped/AMC_742.fasta:4977
# test_op/S2_op_dereped/AMC_122.fasta:4976
# test_op/S2_op_dereped/AMC_280.fasta:4976
# test_op/S2_op_dereped/AMC_184.fasta:4975
# test_op/S2_op_dereped/AMC_257.fasta:4974
# test_op/S2_op_dereped/AMC_453.fasta:4974
# test_op/S2_op_dereped/AMC_196.fasta:4973
# test_op/S2_op_dereped/AMC_631.fasta:4973
# test_op/S2_op_dereped/AMC_834.fasta:4973
# test_op/S2_op_dereped/AMC_74.fasta:4972
# test_op/S2_op_dereped/AMC_129.fasta:4971
# test_op/S2_op_dereped/AMC_25.fasta:4971
# test_op/S2_op_dereped/AMC_281.fasta:4971
# test_op/S2_op_dereped/AMC_500.fasta:4971
# test_op/S2_op_dereped/AMC_677.fasta:4970
# test_op/S2_op_dereped/AMC_973.fasta:4970
# test_op/S2_op_dereped/AMC_522.fasta:4969
# test_op/S2_op_dereped/AMC_422.fasta:4968
# test_op/S2_op_dereped/AMC_550.fasta:4968
# test_op/S2_op_dereped/AMC_518.fasta:4967
# test_op/S2_op_dereped/AMC_529.fasta:4967
# test_op/S2_op_dereped/AMC_950.fasta:4967
# test_op/S2_op_dereped/AMC_912.fasta:4966
# test_op/S2_op_dereped/AMC_821.fasta:4964
# test_op/S2_op_dereped/AMC_878.fasta:4964
# test_op/S2_op_dereped/AMC_611.fasta:4963
# test_op/S2_op_dereped/AMC_616.fasta:4963
# test_op/S2_op_dereped/AMC_746.fasta:4962
# test_op/S2_op_dereped/AMC_261.fasta:4961
# test_op/S2_op_dereped/AMC_387.fasta:4960
# test_op/S2_op_dereped/AMC_549.fasta:4960
# test_op/S2_op_dereped/AMC_870.fasta:4960
# test_op/S2_op_dereped/AMC_221.fasta:4959
# test_op/S2_op_dereped/AMC_459.fasta:4959
# test_op/S2_op_dereped/AMC_680.fasta:4958
# test_op/S2_op_dereped/AMC_486.fasta:4957
# test_op/S2_op_dereped/AMC_813.fasta:4957
# test_op/S2_op_dereped/AMC_962.fasta:4957
# test_op/S2_op_dereped/AMC_744.fasta:4956
# test_op/S2_op_dereped/AMC_810.fasta:4956
# test_op/S2_op_dereped/AMC_639.fasta:4954
# test_op/S2_op_dereped/AMC_270.fasta:4953
# test_op/S2_op_dereped/AMC_481.fasta:4953
# test_op/S2_op_dereped/AMC_249.fasta:4951
# test_op/S2_op_dereped/AMC_212.fasta:4947
# test_op/S2_op_dereped/AMC_286.fasta:4947
# test_op/S2_op_dereped/AMC_633.fasta:4947
# test_op/S2_op_dereped/AMC_695.fasta:4945
# test_op/S2_op_dereped/AMC_131.fasta:4944
# test_op/S2_op_dereped/AMC_259.fasta:4944
# test_op/S2_op_dereped/AMC_469.fasta:4944
# test_op/S2_op_dereped/AMC_555.fasta:4944
# test_op/S2_op_dereped/AMC_563.fasta:4944
# test_op/S2_op_dereped/AMC_645.fasta:4944
# test_op/S2_op_dereped/AMC_719.fasta:4944
# test_op/S2_op_dereped/AMC_845.fasta:4944
# test_op/S2_op_dereped/AMC_700.fasta:4943
# test_op/S2_op_dereped/AMC_107.fasta:4942
# test_op/S2_op_dereped/AMC_132.fasta:4942
# test_op/S2_op_dereped/AMC_367.fasta:4942
# test_op/S2_op_dereped/AMC_753.fasta:4942
# test_op/S2_op_dereped/AMC_123.fasta:4940
# test_op/S2_op_dereped/AMC_273.fasta:4940
# test_op/S2_op_dereped/AMC_595.fasta:4940
# test_op/S2_op_dereped/AMC_724.fasta:4940
# test_op/S2_op_dereped/AMC_740.fasta:4940
# test_op/S2_op_dereped/AMC_859.fasta:4940
# test_op/S2_op_dereped/AMC_394.fasta:4939
# test_op/S2_op_dereped/AMC_598.fasta:4938
# test_op/S2_op_dereped/AMC_671.fasta:4937
# test_op/S2_op_dereped/AMC_710.fasta:4937
# test_op/S2_op_dereped/AMC_137.fasta:4936
# test_op/S2_op_dereped/AMC_722.fasta:4936
# test_op/S2_op_dereped/AMC_18.fasta:4935
# test_op/S2_op_dereped/AMC_215.fasta:4935
# test_op/S2_op_dereped/AMC_385.fasta:4935
# test_op/S2_op_dereped/AMC_551.fasta:4935
# test_op/S2_op_dereped/AMC_432.fasta:4934
# test_op/S2_op_dereped/AMC_478.fasta:4933
# test_op/S2_op_dereped/AMC_721.fasta:4933
# test_op/S2_op_dereped/AMC_945.fasta:4933
# test_op/S2_op_dereped/AMC_698.fasta:4932
# test_op/S2_op_dereped/AMC_826.fasta:4932
# test_op/S2_op_dereped/AMC_868.fasta:4932
# test_op/S2_op_dereped/AMC_381.fasta:4931
# test_op/S2_op_dereped/AMC_768.fasta:4931
# test_op/S2_op_dereped/AMC_245.fasta:4930
# test_op/S2_op_dereped/AMC_637.fasta:4930
# test_op/S2_op_dereped/AMC_320.fasta:4929
# test_op/S2_op_dereped/AMC_50.fasta:4929
# test_op/S2_op_dereped/AMC_830.fasta:4929
# test_op/S2_op_dereped/AMC_627.fasta:4928
# test_op/S2_op_dereped/AMC_778.fasta:4928
# test_op/S2_op_dereped/AMC_793.fasta:4928
# test_op/S2_op_dereped/AMC_897.fasta:4928
# test_op/S2_op_dereped/AMC_949.fasta:4928
# test_op/S2_op_dereped/AMC_176.fasta:4927
# test_op/S2_op_dereped/AMC_246.fasta:4926
# test_op/S2_op_dereped/AMC_360.fasta:4926
# test_op/S2_op_dereped/AMC_809.fasta:4926
# test_op/S2_op_dereped/AMC_881.fasta:4926
# test_op/S2_op_dereped/AMC_900.fasta:4924
# test_op/S2_op_dereped/AMC_378.fasta:4921
# test_op/S2_op_dereped/AMC_603.fasta:4921
# test_op/S2_op_dereped/AMC_91.fasta:4921
# test_op/S2_op_dereped/AMC_460.fasta:4920
# test_op/S2_op_dereped/AMC_907.fasta:4920
# test_op/S2_op_dereped/AMC_26.fasta:4919
# test_op/S2_op_dereped/AMC_663.fasta:4919
# test_op/S2_op_dereped/AMC_914.fasta:4919
# test_op/S2_op_dereped/AMC_919.fasta:4919
# test_op/S2_op_dereped/AMC_336.fasta:4918
# test_op/S2_op_dereped/AMC_850.fasta:4918
# test_op/S2_op_dereped/AMC_373.fasta:4917
# test_op/S2_op_dereped/AMC_535.fasta:4917
# test_op/S2_op_dereped/AMC_583.fasta:4917
# test_op/S2_op_dereped/AMC_584.fasta:4917
# test_op/S2_op_dereped/AMC_841.fasta:4917
# test_op/S2_op_dereped/AMC_185.fasta:4916
# test_op/S2_op_dereped/AMC_233.fasta:4916
# test_op/S2_op_dereped/AMC_150.fasta:4914
# test_op/S2_op_dereped/AMC_624.fasta:4914
# test_op/S2_op_dereped/AMC_125.fasta:4913
# test_op/S2_op_dereped/AMC_325.fasta:4913
# test_op/S2_op_dereped/AMC_146.fasta:4912
# test_op/S2_op_dereped/AMC_406.fasta:4912
# test_op/S2_op_dereped/AMC_60.fasta:4912
# test_op/S2_op_dereped/AMC_743.fasta:4912
# test_op/S2_op_dereped/AMC_543.fasta:4911
# test_op/S2_op_dereped/AMC_335.fasta:4909
# test_op/S2_op_dereped/AMC_464.fasta:4909
# test_op/S2_op_dereped/AMC_612.fasta:4909
# test_op/S2_op_dereped/AMC_516.fasta:4908
# test_op/S2_op_dereped/AMC_567.fasta:4908
# test_op/S2_op_dereped/AMC_737.fasta:4908
# test_op/S2_op_dereped/AMC_181.fasta:4906
# test_op/S2_op_dereped/AMC_96.fasta:4906
# test_op/S2_op_dereped/AMC_343.fasta:4905
# test_op/S2_op_dereped/AMC_580.fasta:4905
# test_op/S2_op_dereped/AMC_880.fasta:4905
# test_op/S2_op_dereped/AMC_955.fasta:4904
# test_op/S2_op_dereped/AMC_561.fasta:4903
# test_op/S2_op_dereped/AMC_747.fasta:4903
# test_op/S2_op_dereped/AMC_960.fasta:4903
# test_op/S2_op_dereped/AMC_202.fasta:4902
# test_op/S2_op_dereped/AMC_541.fasta:4901
# test_op/S2_op_dereped/AMC_575.fasta:4901
# test_op/S2_op_dereped/AMC_7.fasta:4901
# test_op/S2_op_dereped/AMC_942.fasta:4901
# test_op/S2_op_dereped/AMC_426.fasta:4899
# test_op/S2_op_dereped/AMC_542.fasta:4899
# test_op/S2_op_dereped/AMC_635.fasta:4899
# test_op/S2_op_dereped/AMC_89.fasta:4898
# test_op/S2_op_dereped/AMC_232.fasta:4897
# test_op/S2_op_dereped/AMC_260.fasta:4897
# test_op/S2_op_dereped/AMC_537.fasta:4897
# test_op/S2_op_dereped/AMC_72.fasta:4897
# test_op/S2_op_dereped/AMC_392.fasta:4896
# test_op/S2_op_dereped/AMC_838.fasta:4896
# test_op/S2_op_dereped/AMC_895.fasta:4896
# test_op/S2_op_dereped/AMC_346.fasta:4895
# test_op/S2_op_dereped/AMC_456.fasta:4895
# test_op/S2_op_dereped/AMC_521.fasta:4895
# test_op/S2_op_dereped/AMC_484.fasta:4893
# test_op/S2_op_dereped/AMC_566.fasta:4893
# test_op/S2_op_dereped/AMC_618.fasta:4893
# test_op/S2_op_dereped/AMC_755.fasta:4893
# test_op/S2_op_dereped/AMC_905.fasta:4893
# test_op/S2_op_dereped/AMC_379.fasta:4892
# test_op/S2_op_dereped/AMC_933.fasta:4892
# test_op/S2_op_dereped/AMC_503.fasta:4891
# test_op/S2_op_dereped/AMC_593.fasta:4891
# test_op/S2_op_dereped/AMC_538.fasta:4890
# test_op/S2_op_dereped/AMC_439.fasta:4889
# test_op/S2_op_dereped/AMC_697.fasta:4889
# test_op/S2_op_dereped/AMC_824.fasta:4889
# test_op/S2_op_dereped/AMC_536.fasta:4887
# test_op/S2_op_dereped/AMC_717.fasta:4887
# test_op/S2_op_dereped/AMC_965.fasta:4887
# test_op/S2_op_dereped/AMC_110.fasta:4886
# test_op/S2_op_dereped/AMC_331.fasta:4886
# test_op/S2_op_dereped/AMC_38.fasta:4886
# test_op/S2_op_dereped/AMC_12.fasta:4885
# test_op/S2_op_dereped/AMC_403.fasta:4885
# test_op/S2_op_dereped/AMC_1.fasta:4884
# test_op/S2_op_dereped/AMC_124.fasta:4884
# test_op/S2_op_dereped/AMC_163.fasta:4884
# test_op/S2_op_dereped/AMC_244.fasta:4884
# test_op/S2_op_dereped/AMC_582.fasta:4883
# test_op/S2_op_dereped/AMC_879.fasta:4883
# test_op/S2_op_dereped/AMC_141.fasta:4882
# test_op/S2_op_dereped/AMC_856.fasta:4882
# test_op/S2_op_dereped/AMC_225.fasta:4881
# test_op/S2_op_dereped/AMC_577.fasta:4881
# test_op/S2_op_dereped/AMC_67.fasta:4881
# test_op/S2_op_dereped/AMC_748.fasta:4880
# test_op/S2_op_dereped/AMC_689.fasta:4879
# test_op/S2_op_dereped/AMC_735.fasta:4879
# test_op/S2_op_dereped/AMC_119.fasta:4877
# test_op/S2_op_dereped/AMC_32.fasta:4877
# test_op/S2_op_dereped/AMC_413.fasta:4877
# test_op/S2_op_dereped/AMC_483.fasta:4877
# test_op/S2_op_dereped/AMC_681.fasta:4877
# test_op/S2_op_dereped/AMC_54.fasta:4876
# test_op/S2_op_dereped/AMC_470.fasta:4874
# test_op/S2_op_dereped/AMC_552.fasta:4874
# test_op/S2_op_dereped/AMC_70.fasta:4874
# test_op/S2_op_dereped/AMC_846.fasta:4874
# test_op/S2_op_dereped/AMC_162.fasta:4873
# test_op/S2_op_dereped/AMC_27.fasta:4873
# test_op/S2_op_dereped/AMC_408.fasta:4873
# test_op/S2_op_dereped/AMC_440.fasta:4873
# test_op/S2_op_dereped/AMC_571.fasta:4873
# test_op/S2_op_dereped/AMC_275.fasta:4871
# test_op/S2_op_dereped/AMC_594.fasta:4870
# test_op/S2_op_dereped/AMC_672.fasta:4870
# test_op/S2_op_dereped/AMC_303.fasta:4869
# test_op/S2_op_dereped/AMC_466.fasta:4869
# test_op/S2_op_dereped/AMC_750.fasta:4869
# test_op/S2_op_dereped/AMC_899.fasta:4869
# test_op/S2_op_dereped/AMC_15.fasta:4868
# test_op/S2_op_dereped/AMC_256.fasta:4868
# test_op/S2_op_dereped/AMC_350.fasta:4868
# test_op/S2_op_dereped/AMC_382.fasta:4868
# test_op/S2_op_dereped/AMC_253.fasta:4867
# test_op/S2_op_dereped/AMC_910.fasta:4867
# test_op/S2_op_dereped/AMC_111.fasta:4866
# test_op/S2_op_dereped/AMC_149.fasta:4865
# test_op/S2_op_dereped/AMC_840.fasta:4865
# test_op/S2_op_dereped/AMC_147.fasta:4864
# test_op/S2_op_dereped/AMC_658.fasta:4864
# test_op/S2_op_dereped/AMC_468.fasta:4863
# test_op/S2_op_dereped/AMC_510.fasta:4863
# test_op/S2_op_dereped/AMC_143.fasta:4861
# test_op/S2_op_dereped/AMC_474.fasta:4860
# test_op/S2_op_dereped/AMC_591.fasta:4860
# test_op/S2_op_dereped/AMC_638.fasta:4860
# test_op/S2_op_dereped/AMC_69.fasta:4860
# test_op/S2_op_dereped/AMC_409.fasta:4859
# test_op/S2_op_dereped/AMC_776.fasta:4858
# test_op/S2_op_dereped/AMC_959.fasta:4858
# test_op/S2_op_dereped/AMC_808.fasta:4856
# test_op/S2_op_dereped/AMC_849.fasta:4856
# test_op/S2_op_dereped/AMC_355.fasta:4855
# test_op/S2_op_dereped/AMC_626.fasta:4855
# test_op/S2_op_dereped/AMC_29.fasta:4854
# test_op/S2_op_dereped/AMC_576.fasta:4854
# test_op/S2_op_dereped/AMC_625.fasta:4854
# test_op/S2_op_dereped/AMC_733.fasta:4854
# test_op/S2_op_dereped/AMC_792.fasta:4854
# test_op/S2_op_dereped/AMC_391.fasta:4853
# test_op/S2_op_dereped/AMC_505.fasta:4853
# test_op/S2_op_dereped/AMC_805.fasta:4853
# test_op/S2_op_dereped/AMC_848.fasta:4853
# test_op/S2_op_dereped/AMC_655.fasta:4852
# test_op/S2_op_dereped/AMC_832.fasta:4852
# test_op/S2_op_dereped/AMC_116.fasta:4851
# test_op/S2_op_dereped/AMC_324.fasta:4851
# test_op/S2_op_dereped/AMC_467.fasta:4851
# test_op/S2_op_dereped/AMC_77.fasta:4851
# test_op/S2_op_dereped/AMC_372.fasta:4850
# test_op/S2_op_dereped/AMC_572.fasta:4850
# test_op/S2_op_dereped/AMC_921.fasta:4850
# test_op/S2_op_dereped/AMC_438.fasta:4849
# test_op/S2_op_dereped/AMC_6.fasta:4849
# test_op/S2_op_dereped/AMC_794.fasta:4849
# test_op/S2_op_dereped/AMC_889.fasta:4848
# test_op/S2_op_dereped/AMC_30.fasta:4847
# test_op/S2_op_dereped/AMC_333.fasta:4844
# test_op/S2_op_dereped/AMC_718.fasta:4844
# test_op/S2_op_dereped/AMC_238.fasta:4843
# test_op/S2_op_dereped/AMC_283.fasta:4843
# test_op/S2_op_dereped/AMC_523.fasta:4843
# test_op/S2_op_dereped/AMC_807.fasta:4843
# test_op/S2_op_dereped/AMC_934.fasta:4843
# test_op/S2_op_dereped/AMC_662.fasta:4842
# test_op/S2_op_dereped/AMC_770.fasta:4842
# test_op/S2_op_dereped/AMC_918.fasta:4842
# test_op/S2_op_dereped/AMC_144.fasta:4841
# test_op/S2_op_dereped/AMC_165.fasta:4841
# test_op/S2_op_dereped/AMC_477.fasta:4841
# test_op/S2_op_dereped/AMC_652.fasta:4841
# test_op/S2_op_dereped/AMC_608.fasta:4840
# test_op/S2_op_dereped/AMC_557.fasta:4838
# test_op/S2_op_dereped/AMC_57.fasta:4838
# test_op/S2_op_dereped/AMC_252.fasta:4837
# test_op/S2_op_dereped/AMC_405.fasta:4837
# test_op/S2_op_dereped/AMC_430.fasta:4837
# test_op/S2_op_dereped/AMC_858.fasta:4837
# test_op/S2_op_dereped/AMC_127.fasta:4836
# test_op/S2_op_dereped/AMC_166.fasta:4836
# test_op/S2_op_dereped/AMC_329.fasta:4836
# test_op/S2_op_dereped/AMC_694.fasta:4836
# test_op/S2_op_dereped/AMC_190.fasta:4835
# test_op/S2_op_dereped/AMC_448.fasta:4835
# test_op/S2_op_dereped/AMC_533.fasta:4835
# test_op/S2_op_dereped/AMC_757.fasta:4835
# test_op/S2_op_dereped/AMC_187.fasta:4834
# test_op/S2_op_dereped/AMC_52.fasta:4834
# test_op/S2_op_dereped/AMC_95.fasta:4834
# test_op/S2_op_dereped/AMC_168.fasta:4833
# test_op/S2_op_dereped/AMC_242.fasta:4833
# test_op/S2_op_dereped/AMC_520.fasta:4833
# test_op/S2_op_dereped/AMC_531.fasta:4833
# test_op/S2_op_dereped/AMC_687.fasta:4833
# test_op/S2_op_dereped/AMC_371.fasta:4831
# test_op/S2_op_dereped/AMC_756.fasta:4831
# test_op/S2_op_dereped/AMC_716.fasta:4830
# test_op/S2_op_dereped/AMC_208.fasta:4829
# test_op/S2_op_dereped/AMC_565.fasta:4828
# test_op/S2_op_dereped/AMC_613.fasta:4828
# test_op/S2_op_dereped/AMC_726.fasta:4828
# test_op/S2_op_dereped/AMC_906.fasta:4828
# test_op/S2_op_dereped/AMC_831.fasta:4827
# test_op/S2_op_dereped/AMC_904.fasta:4827
# test_op/S2_op_dereped/AMC_941.fasta:4827
# test_op/S2_op_dereped/AMC_173.fasta:4826
# test_op/S2_op_dereped/AMC_236.fasta:4825
# test_op/S2_op_dereped/AMC_452.fasta:4825
# test_op/S2_op_dereped/AMC_49.fasta:4825
# test_op/S2_op_dereped/AMC_55.fasta:4825
# test_op/S2_op_dereped/AMC_801.fasta:4825
# test_op/S2_op_dereped/AMC_13.fasta:4824
# test_op/S2_op_dereped/AMC_957.fasta:4824
# test_op/S2_op_dereped/AMC_610.fasta:4823
# test_op/S2_op_dereped/AMC_843.fasta:4822
# test_op/S2_op_dereped/AMC_213.fasta:4821
# test_op/S2_op_dereped/AMC_953.fasta:4821
# test_op/S2_op_dereped/AMC_35.fasta:4820
# test_op/S2_op_dereped/AMC_620.fasta:4820
# test_op/S2_op_dereped/AMC_773.fasta:4820
# test_op/S2_op_dereped/AMC_51.fasta:4819
# test_op/S2_op_dereped/AMC_23.fasta:4817
# test_op/S2_op_dereped/AMC_255.fasta:4817
# test_op/S2_op_dereped/AMC_47.fasta:4817
# test_op/S2_op_dereped/AMC_862.fasta:4817
# test_op/S2_op_dereped/AMC_243.fasta:4816
# test_op/S2_op_dereped/AMC_59.fasta:4816
# test_op/S2_op_dereped/AMC_708.fasta:4816
# test_op/S2_op_dereped/AMC_790.fasta:4816
# test_op/S2_op_dereped/AMC_186.fasta:4815
# test_op/S2_op_dereped/AMC_210.fasta:4815
# test_op/S2_op_dereped/AMC_383.fasta:4815
# test_op/S2_op_dereped/AMC_798.fasta:4815
# test_op/S2_op_dereped/AMC_167.fasta:4811
# test_op/S2_op_dereped/AMC_775.fasta:4811
# test_op/S2_op_dereped/AMC_106.fasta:4810
# test_op/S2_op_dereped/AMC_192.fasta:4810
# test_op/S2_op_dereped/AMC_40.fasta:4810
# test_op/S2_op_dereped/AMC_728.fasta:4810
# test_op/S2_op_dereped/AMC_656.fasta:4809
# test_op/S2_op_dereped/AMC_765.fasta:4809
# test_op/S2_op_dereped/AMC_314.fasta:4808
# test_op/S2_op_dereped/AMC_730.fasta:4808
# test_op/S2_op_dereped/AMC_732.fasta:4808
# test_op/S2_op_dereped/AMC_929.fasta:4808
# test_op/S2_op_dereped/AMC_389.fasta:4807
# test_op/S2_op_dereped/AMC_390.fasta:4807
# test_op/S2_op_dereped/AMC_705.fasta:4807
# test_op/S2_op_dereped/AMC_887.fasta:4807
# test_op/S2_op_dereped/AMC_136.fasta:4806
# test_op/S2_op_dereped/AMC_682.fasta:4806
# test_op/S2_op_dereped/AMC_214.fasta:4805
# test_op/S2_op_dereped/AMC_337.fasta:4803
# test_op/S2_op_dereped/AMC_288.fasta:4802
# test_op/S2_op_dereped/AMC_347.fasta:4802
# test_op/S2_op_dereped/AMC_738.fasta:4802
# test_op/S2_op_dereped/AMC_823.fasta:4802
# test_op/S2_op_dereped/AMC_287.fasta:4801
# test_op/S2_op_dereped/AMC_893.fasta:4801
# test_op/S2_op_dereped/AMC_34.fasta:4800
# test_op/S2_op_dereped/AMC_489.fasta:4800
# test_op/S2_op_dereped/AMC_678.fasta:4800
# test_op/S2_op_dereped/AMC_319.fasta:4799
# test_op/S2_op_dereped/AMC_218.fasta:4798
# test_op/S2_op_dereped/AMC_404.fasta:4798
# test_op/S2_op_dereped/AMC_867.fasta:4798
# test_op/S2_op_dereped/AMC_896.fasta:4796
# test_op/S2_op_dereped/AMC_322.fasta:4795
# test_op/S2_op_dereped/AMC_654.fasta:4795
# test_op/S2_op_dereped/AMC_951.fasta:4794
# test_op/S2_op_dereped/AMC_237.fasta:4793
# test_op/S2_op_dereped/AMC_800.fasta:4793
# test_op/S2_op_dereped/AMC_873.fasta:4793
# test_op/S2_op_dereped/AMC_494.fasta:4792
# test_op/S2_op_dereped/AMC_524.fasta:4792
# test_op/S2_op_dereped/AMC_547.fasta:4792
# test_op/S2_op_dereped/AMC_548.fasta:4792
# test_op/S2_op_dereped/AMC_315.fasta:4791
# test_op/S2_op_dereped/AMC_446.fasta:4791
# test_op/S2_op_dereped/AMC_449.fasta:4791
# test_op/S2_op_dereped/AMC_513.fasta:4791
# test_op/S2_op_dereped/AMC_519.fasta:4791
# test_op/S2_op_dereped/AMC_605.fasta:4791
# test_op/S2_op_dereped/AMC_43.fasta:4790
# test_op/S2_op_dereped/AMC_935.fasta:4789
# test_op/S2_op_dereped/AMC_276.fasta:4787
# test_op/S2_op_dereped/AMC_766.fasta:4787
# test_op/S2_op_dereped/AMC_138.fasta:4786
# test_op/S2_op_dereped/AMC_21.fasta:4785
# test_op/S2_op_dereped/AMC_297.fasta:4785
# test_op/S2_op_dereped/AMC_530.fasta:4785
# test_op/S2_op_dereped/AMC_581.fasta:4784
# test_op/S2_op_dereped/AMC_619.fasta:4784
# test_op/S2_op_dereped/AMC_970.fasta:4784
# test_op/S2_op_dereped/AMC_416.fasta:4783
# test_op/S2_op_dereped/AMC_461.fasta:4783
# test_op/S2_op_dereped/AMC_517.fasta:4783
# test_op/S2_op_dereped/AMC_128.fasta:4782
# test_op/S2_op_dereped/AMC_156.fasta:4782
# test_op/S2_op_dereped/AMC_600.fasta:4782
# test_op/S2_op_dereped/AMC_712.fasta:4782
# test_op/S2_op_dereped/AMC_152.fasta:4781
# test_op/S2_op_dereped/AMC_445.fasta:4781
# test_op/S2_op_dereped/AMC_458.fasta:4781
# test_op/S2_op_dereped/AMC_525.fasta:4780
# test_op/S2_op_dereped/AMC_851.fasta:4780
# test_op/S2_op_dereped/AMC_928.fasta:4780
# test_op/S2_op_dereped/AMC_683.fasta:4778
# test_op/S2_op_dereped/AMC_829.fasta:4778
# test_op/S2_op_dereped/AMC_946.fasta:4778
# test_op/S2_op_dereped/AMC_140.fasta:4776
# test_op/S2_op_dereped/AMC_418.fasta:4776
# test_op/S2_op_dereped/AMC_607.fasta:4775
# test_op/S2_op_dereped/AMC_886.fasta:4775
# test_op/S2_op_dereped/AMC_117.fasta:4774
# test_op/S2_op_dereped/AMC_205.fasta:4773
# test_op/S2_op_dereped/AMC_660.fasta:4773
# test_op/S2_op_dereped/AMC_723.fasta:4773
# test_op/S2_op_dereped/AMC_731.fasta:4773
# test_op/S2_op_dereped/AMC_309.fasta:4772
# test_op/S2_op_dereped/AMC_534.fasta:4771
# test_op/S2_op_dereped/AMC_702.fasta:4771
# test_op/S2_op_dereped/AMC_457.fasta:4770
# test_op/S2_op_dereped/AMC_11.fasta:4769
# test_op/S2_op_dereped/AMC_407.fasta:4768
# test_op/S2_op_dereped/AMC_472.fasta:4768
# test_op/S2_op_dereped/AMC_307.fasta:4767
# test_op/S2_op_dereped/AMC_545.fasta:4766
# test_op/S2_op_dereped/AMC_247.fasta:4764
# test_op/S2_op_dereped/AMC_720.fasta:4764
# test_op/S2_op_dereped/AMC_427.fasta:4763
# test_op/S2_op_dereped/AMC_463.fasta:4763
# test_op/S2_op_dereped/AMC_79.fasta:4763
# test_op/S2_op_dereped/AMC_891.fasta:4763
# test_op/S2_op_dereped/AMC_932.fasta:4762
# test_op/S2_op_dereped/AMC_298.fasta:4761
# test_op/S2_op_dereped/AMC_58.fasta:4761
# test_op/S2_op_dereped/AMC_68.fasta:4761
# test_op/S2_op_dereped/AMC_761.fasta:4761
# test_op/S2_op_dereped/AMC_269.fasta:4760
# test_op/S2_op_dereped/AMC_356.fasta:4760
# test_op/S2_op_dereped/AMC_508.fasta:4760
# test_op/S2_op_dereped/AMC_195.fasta:4759
# test_op/S2_op_dereped/AMC_642.fasta:4759
# test_op/S2_op_dereped/AMC_451.fasta:4758
# test_op/S2_op_dereped/AMC_437.fasta:4757
# test_op/S2_op_dereped/AMC_727.fasta:4756
# test_op/S2_op_dereped/AMC_787.fasta:4756
# test_op/S2_op_dereped/AMC_327.fasta:4755
# test_op/S2_op_dereped/AMC_4.fasta:4755
# test_op/S2_op_dereped/AMC_802.fasta:4755
# test_op/S2_op_dereped/AMC_339.fasta:4754
# test_op/S2_op_dereped/AMC_924.fasta:4754
# test_op/S2_op_dereped/AMC_354.fasta:4753
# test_op/S2_op_dereped/AMC_502.fasta:4751
# test_op/S2_op_dereped/AMC_211.fasta:4750
# test_op/S2_op_dereped/AMC_424.fasta:4750
# test_op/S2_op_dereped/AMC_785.fasta:4748
# test_op/S2_op_dereped/AMC_105.fasta:4747
# test_op/S2_op_dereped/AMC_471.fasta:4746
# test_op/S2_op_dereped/AMC_786.fasta:4746
# test_op/S2_op_dereped/AMC_134.fasta:4745
# test_op/S2_op_dereped/AMC_623.fasta:4745
# test_op/S2_op_dereped/AMC_684.fasta:4745
# test_op/S2_op_dereped/AMC_374.fasta:4744
# test_op/S2_op_dereped/AMC_182.fasta:4743
# test_op/S2_op_dereped/AMC_348.fasta:4743
# test_op/S2_op_dereped/AMC_36.fasta:4742
# test_op/S2_op_dereped/AMC_423.fasta:4742
# test_op/S2_op_dereped/AMC_496.fasta:4742
# test_op/S2_op_dereped/AMC_574.fasta:4742
# test_op/S2_op_dereped/AMC_528.fasta:4741
# test_op/S2_op_dereped/AMC_752.fasta:4741
# test_op/S2_op_dereped/AMC_78.fasta:4741
# test_op/S2_op_dereped/AMC_817.fasta:4741
# test_op/S2_op_dereped/AMC_479.fasta:4740
# test_op/S2_op_dereped/AMC_366.fasta:4739
# test_op/S2_op_dereped/AMC_415.fasta:4739
# test_op/S2_op_dereped/AMC_103.fasta:4738
# test_op/S2_op_dereped/AMC_668.fasta:4738
# test_op/S2_op_dereped/AMC_898.fasta:4738
# test_op/S2_op_dereped/AMC_171.fasta:4737
# test_op/S2_op_dereped/AMC_20.fasta:4737
# test_op/S2_op_dereped/AMC_511.fasta:4737
# test_op/S2_op_dereped/AMC_657.fasta:4737
# test_op/S2_op_dereped/AMC_310.fasta:4736
# test_op/S2_op_dereped/AMC_114.fasta:4735
# test_op/S2_op_dereped/AMC_692.fasta:4735
# test_op/S2_op_dereped/AMC_835.fasta:4735
# test_op/S2_op_dereped/AMC_290.fasta:4734
# test_op/S2_op_dereped/AMC_401.fasta:4734
# test_op/S2_op_dereped/AMC_771.fasta:4734
# test_op/S2_op_dereped/AMC_842.fasta:4734
# test_op/S2_op_dereped/AMC_251.fasta:4733
# test_op/S2_op_dereped/AMC_397.fasta:4733
# test_op/S2_op_dereped/AMC_647.fasta:4732
# test_op/S2_op_dereped/AMC_865.fasta:4731
# test_op/S2_op_dereped/AMC_139.fasta:4730
# test_op/S2_op_dereped/AMC_715.fasta:4730
# test_op/S2_op_dereped/AMC_814.fasta:4730
# test_op/S2_op_dereped/AMC_877.fasta:4730
# test_op/S2_op_dereped/AMC_402.fasta:4728
# test_op/S2_op_dereped/AMC_200.fasta:4727
# test_op/S2_op_dereped/AMC_777.fasta:4727
# test_op/S2_op_dereped/AMC_828.fasta:4727
# test_op/S2_op_dereped/AMC_659.fasta:4726
# test_op/S2_op_dereped/AMC_944.fasta:4725
# test_op/S2_op_dereped/AMC_885.fasta:4724
# test_op/S2_op_dereped/AMC_883.fasta:4723
# test_op/S2_op_dereped/AMC_109.fasta:4720
# test_op/S2_op_dereped/AMC_362.fasta:4719
# test_op/S2_op_dereped/AMC_14.fasta:4718
# test_op/S2_op_dereped/AMC_41.fasta:4717
# test_op/S2_op_dereped/AMC_788.fasta:4715
# test_op/S2_op_dereped/AMC_0.fasta:4714
# test_op/S2_op_dereped/AMC_434.fasta:4714
# test_op/S2_op_dereped/AMC_713.fasta:4714
# test_op/S2_op_dereped/AMC_734.fasta:4714
# test_op/S2_op_dereped/AMC_102.fasta:4712
# test_op/S2_op_dereped/AMC_108.fasta:4712
# test_op/S2_op_dereped/AMC_501.fasta:4711
# test_op/S2_op_dereped/AMC_63.fasta:4711
# test_op/S2_op_dereped/AMC_31.fasta:4710
# test_op/S2_op_dereped/AMC_240.fasta:4709
# test_op/S2_op_dereped/AMC_797.fasta:4709
# test_op/S2_op_dereped/AMC_305.fasta:4708
# test_op/S2_op_dereped/AMC_972.fasta:4707
# test_op/S2_op_dereped/AMC_827.fasta:4706
# test_op/S2_op_dereped/AMC_17.fasta:4705
# test_op/S2_op_dereped/AMC_178.fasta:4705
# test_op/S2_op_dereped/AMC_857.fasta:4705
# test_op/S2_op_dereped/AMC_454.fasta:4704
# test_op/S2_op_dereped/AMC_417.fasta:4702
# test_op/S2_op_dereped/AMC_704.fasta:4702
# test_op/S2_op_dereped/AMC_709.fasta:4702
# test_op/S2_op_dereped/AMC_16.fasta:4701
# test_op/S2_op_dereped/AMC_357.fasta:4699
# test_op/S2_op_dereped/AMC_425.fasta:4699
# test_op/S2_op_dereped/AMC_875.fasta:4697
# test_op/S2_op_dereped/AMC_573.fasta:4696
# test_op/S2_op_dereped/AMC_157.fasta:4695
# test_op/S2_op_dereped/AMC_507.fasta:4694
# test_op/S2_op_dereped/AMC_126.fasta:4693
# test_op/S2_op_dereped/AMC_428.fasta:4693
# test_op/S2_op_dereped/AMC_197.fasta:4692
# test_op/S2_op_dereped/AMC_570.fasta:4692
# test_op/S2_op_dereped/AMC_250.fasta:4691
# test_op/S2_op_dereped/AMC_554.fasta:4691
# test_op/S2_op_dereped/AMC_46.fasta:4690
# test_op/S2_op_dereped/AMC_822.fasta:4690
# test_op/S2_op_dereped/AMC_546.fasta:4689
# test_op/S2_op_dereped/AMC_908.fasta:4688
# test_op/S2_op_dereped/AMC_62.fasta:4687
# test_op/S2_op_dereped/AMC_819.fasta:4687
# test_op/S2_op_dereped/AMC_222.fasta:4686
# test_op/S2_op_dereped/AMC_475.fasta:4684
# test_op/S2_op_dereped/AMC_80.fasta:4683
# test_op/S2_op_dereped/AMC_22.fasta:4682
# test_op/S2_op_dereped/AMC_300.fasta:4682
# test_op/S2_op_dereped/AMC_170.fasta:4681
# test_op/S2_op_dereped/AMC_28.fasta:4681
# test_op/S2_op_dereped/AMC_943.fasta:4681
# test_op/S2_op_dereped/AMC_506.fasta:4679
# test_op/S2_op_dereped/AMC_630.fasta:4678
# test_op/S2_op_dereped/AMC_435.fasta:4677
# test_op/S2_op_dereped/AMC_353.fasta:4675
# test_op/S2_op_dereped/AMC_818.fasta:4675
# test_op/S2_op_dereped/AMC_648.fasta:4673
# test_op/S2_op_dereped/AMC_864.fasta:4673
# test_op/S2_op_dereped/AMC_954.fasta:4673
# test_op/S2_op_dereped/AMC_968.fasta:4673
# test_op/S2_op_dereped/AMC_509.fasta:4671
# test_op/S2_op_dereped/AMC_636.fasta:4671
# test_op/S2_op_dereped/AMC_729.fasta:4666
# test_op/S2_op_dereped/AMC_291.fasta:4665
# test_op/S2_op_dereped/AMC_491.fasta:4665
# test_op/S2_op_dereped/AMC_711.fasta:4665
# test_op/S2_op_dereped/AMC_512.fasta:4664
# test_op/S2_op_dereped/AMC_169.fasta:4663
# test_op/S2_op_dereped/AMC_313.fasta:4663
# test_op/S2_op_dereped/AMC_421.fasta:4662
# test_op/S2_op_dereped/AMC_920.fasta:4662
# test_op/S2_op_dereped/AMC_433.fasta:4661
# test_op/S2_op_dereped/AMC_653.fasta:4661
# test_op/S2_op_dereped/AMC_326.fasta:4660
# test_op/S2_op_dereped/AMC_480.fasta:4659
# test_op/S2_op_dereped/AMC_384.fasta:4658
# test_op/S2_op_dereped/AMC_811.fasta:4658
# test_op/S2_op_dereped/AMC_599.fasta:4657
# test_op/S2_op_dereped/AMC_634.fasta:4656
# test_op/S2_op_dereped/AMC_806.fasta:4656
# test_op/S2_op_dereped/AMC_203.fasta:4655
# test_op/S2_op_dereped/AMC_191.fasta:4654
# test_op/S2_op_dereped/AMC_913.fasta:4653
# test_op/S2_op_dereped/AMC_795.fasta:4652
# test_op/S2_op_dereped/AMC_45.fasta:4651
# test_op/S2_op_dereped/AMC_925.fasta:4651
# test_op/S2_op_dereped/AMC_388.fasta:4650
# test_op/S2_op_dereped/AMC_358.fasta:4649
# test_op/S2_op_dereped/AMC_736.fasta:4648
# test_op/S2_op_dereped/AMC_145.fasta:4646
# test_op/S2_op_dereped/AMC_911.fasta:4646
# test_op/S2_op_dereped/AMC_282.fasta:4643
# test_op/S2_op_dereped/AMC_504.fasta:4643
# test_op/S2_op_dereped/AMC_100.fasta:4641
# test_op/S2_op_dereped/AMC_294.fasta:4641
# test_op/S2_op_dereped/AMC_447.fasta:4641
# test_op/S2_op_dereped/AMC_488.fasta:4640
# test_op/S2_op_dereped/AMC_679.fasta:4640
# test_op/S2_op_dereped/AMC_341.fasta:4639
# test_op/S2_op_dereped/AMC_399.fasta:4638
# test_op/S2_op_dereped/AMC_532.fasta:4637
# test_op/S2_op_dereped/AMC_115.fasta:4636
# test_op/S2_op_dereped/AMC_189.fasta:4635
# test_op/S2_op_dereped/AMC_2.fasta:4635
# test_op/S2_op_dereped/AMC_414.fasta:4635
# test_op/S2_op_dereped/AMC_784.fasta:4634
# test_op/S2_op_dereped/AMC_311.fasta:4632
# test_op/S2_op_dereped/AMC_328.fasta:4632
# test_op/S2_op_dereped/AMC_592.fasta:4632
# test_op/S2_op_dereped/AMC_820.fasta:4632
# test_op/S2_op_dereped/AMC_118.fasta:4629
# test_op/S2_op_dereped/AMC_153.fasta:4629
# test_op/S2_op_dereped/AMC_825.fasta:4627
# test_op/S2_op_dereped/AMC_289.fasta:4625
# test_op/S2_op_dereped/AMC_871.fasta:4621
# test_op/S2_op_dereped/AMC_937.fasta:4618
# test_op/S2_op_dereped/AMC_411.fasta:4616
# test_op/S2_op_dereped/AMC_279.fasta:4615
# test_op/S2_op_dereped/AMC_839.fasta:4614
# test_op/S2_op_dereped/AMC_239.fasta:4613
# test_op/S2_op_dereped/AMC_295.fasta:4613
# test_op/S2_op_dereped/AMC_691.fasta:4613
# test_op/S2_op_dereped/AMC_142.fasta:4612
# test_op/S2_op_dereped/AMC_71.fasta:4608
# test_op/S2_op_dereped/AMC_617.fasta:4605
# test_op/S2_op_dereped/AMC_861.fasta:4603
# test_op/S2_op_dereped/AMC_370.fasta:4600
# test_op/S2_op_dereped/AMC_725.fasta:4599
# test_op/S2_op_dereped/AMC_767.fasta:4599
# test_op/S2_op_dereped/AMC_579.fasta:4597
# test_op/S2_op_dereped/AMC_644.fasta:4594
# test_op/S2_op_dereped/AMC_791.fasta:4594
# test_op/S2_op_dereped/AMC_876.fasta:4594
# test_op/S2_op_dereped/AMC_92.fasta:4594
# test_op/S2_op_dereped/AMC_495.fasta:4593
# test_op/S2_op_dereped/AMC_98.fasta:4591
# test_op/S2_op_dereped/AMC_135.fasta:4590
# test_op/S2_op_dereped/AMC_674.fasta:4589
# test_op/S2_op_dereped/AMC_860.fasta:4589
# test_op/S2_op_dereped/AMC_780.fasta:4588
# test_op/S2_op_dereped/AMC_376.fasta:4587
# test_op/S2_op_dereped/AMC_154.fasta:4583
# test_op/S2_op_dereped/AMC_188.fasta:4583
# test_op/S2_op_dereped/AMC_306.fasta:4580
# test_op/S2_op_dereped/AMC_361.fasta:4579
# test_op/S2_op_dereped/AMC_88.fasta:4579
# test_op/S2_op_dereped/AMC_714.fasta:4577
# test_op/S2_op_dereped/AMC_888.fasta:4576
# test_op/S2_op_dereped/AMC_296.fasta:4573
# test_op/S2_op_dereped/AMC_443.fasta:4571
# test_op/S2_op_dereped/AMC_917.fasta:4570
# test_op/S2_op_dereped/AMC_345.fasta:4564
# test_op/S2_op_dereped/AMC_302.fasta:4562
# test_op/S2_op_dereped/AMC_10.fasta:4553
# test_op/S2_op_dereped/AMC_304.fasta:4552
# test_op/S2_op_dereped/AMC_703.fasta:4552
# test_op/S2_op_dereped/AMC_940.fasta:4542
# test_op/S2_op_dereped/AMC_909.fasta:4539
# test_op/S2_op_dereped/AMC_235.fasta:4537
# test_op/S2_op_dereped/AMC_774.fasta:4535
# test_op/S2_op_dereped/AMC_338.fasta:4533
# test_op/S2_op_dereped/AMC_265.fasta:4532
# test_op/S2_op_dereped/AMC_37.fasta:4532
# test_op/S2_op_dereped/AMC_560.fasta:4532
# test_op/S2_op_dereped/AMC_230.fasta:4528
# test_op/S2_op_dereped/AMC_398.fasta:4526
# test_op/S2_op_dereped/AMC_601.fasta:4526
# test_op/S2_op_dereped/AMC_254.fasta:4518
# test_op/S2_op_dereped/AMC_344.fasta:4518
# test_op/S2_op_dereped/AMC_836.fasta:4517
# test_op/S2_op_dereped/AMC_936.fasta:4517
# test_op/S2_op_dereped/AMC_308.fasta:4512
# test_op/S2_op_dereped/AMC_606.fasta:4512
# test_op/S2_op_dereped/AMC_559.fasta:4510
# test_op/S2_op_dereped/AMC_268.fasta:4503
# test_op/S2_op_dereped/AMC_216.fasta:4496
# test_op/S2_op_dereped/AMC_53.fasta:4496
# test_op/S2_op_dereped/AMC_248.fasta:4495
# test_op/S2_op_dereped/AMC_916.fasta:4495
# test_op/S2_op_dereped/AMC_101.fasta:4491
# test_op/S2_op_dereped/AMC_745.fasta:4491
# test_op/S2_op_dereped/AMC_803.fasta:4489
# test_op/S2_op_dereped/AMC_24.fasta:4486
# test_op/S2_op_dereped/AMC_419.fasta:4485
# test_op/S2_op_dereped/AMC_804.fasta:4485
# test_op/S2_op_dereped/AMC_901.fasta:4485
# test_op/S2_op_dereped/AMC_363.fasta:4483
# test_op/S2_op_dereped/AMC_274.fasta:4481
# test_op/S2_op_dereped/AMC_206.fasta:4480
# test_op/S2_op_dereped/AMC_589.fasta:4479
# test_op/S2_op_dereped/AMC_377.fasta:4478
# test_op/S2_op_dereped/AMC_224.fasta:4474
# test_op/S2_op_dereped/AMC_349.fasta:4473
# test_op/S2_op_dereped/AMC_455.fasta:4473
# test_op/S2_op_dereped/AMC_527.fasta:4469
# test_op/S2_op_dereped/AMC_855.fasta:4465
# test_op/S2_op_dereped/AMC_293.fasta:4461
# test_op/S2_op_dereped/AMC_194.fasta:4451
# test_op/S2_op_dereped/AMC_963.fasta:4449
# test_op/S2_op_dereped/AMC_966.fasta:4448
# test_op/S2_op_dereped/AMC_87.fasta:4447
# test_op/S2_op_dereped/AMC_8.fasta:4446
# test_op/S2_op_dereped/AMC_264.fasta:4437
# test_op/S2_op_dereped/AMC_365.fasta:4435
# test_op/S2_op_dereped/AMC_209.fasta:4433
# test_op/S2_op_dereped/AMC_262.fasta:4429
# test_op/S2_op_dereped/AMC_927.fasta:4427
# test_op/S2_op_dereped/AMC_562.fasta:4421
# test_op/S2_op_dereped/AMC_764.fasta:4420
# test_op/S2_op_dereped/AMC_76.fasta:4418
# test_op/S2_op_dereped/AMC_323.fasta:4416
# test_op/S2_op_dereped/AMC_368.fasta:4410
# test_op/S2_op_dereped/AMC_783.fasta:4398
# test_op/S2_op_dereped/AMC_278.fasta:4393
# test_op/S2_op_dereped/AMC_33.fasta:4393
# test_op/S2_op_dereped/AMC_922.fasta:4391
# test_op/S2_op_dereped/AMC_497.fasta:4388
# test_op/S2_op_dereped/AMC_853.fasta:4371
# test_op/S2_op_dereped/AMC_597.fasta:4363
# test_op/S2_op_dereped/AMC_317.fasta:4359
# test_op/S2_op_dereped/AMC_93.fasta:4341
# test_op/S2_op_dereped/AMC_696.fasta:4336
# test_op/S2_op_dereped/AMC_234.fasta:4282
# test_op/S2_op_dereped/AMC_321.fasta:4196

# %% [markdown]
# # Step 3 Pre-clustering of using all dereplicated FASTAs and non-redundant genome generation

# %% [markdown]
# Step 3 is the new feature since version `0.1` onward comparing with `0.1Beta`.It performs 100% clustering on all dereplicated FASTAs made in Step 2.<br>
#
# The program of Step 3 will take the **dereplicated fasta files made in step 3 as input**, and produce:<br>
# * dereplicated concatenated FASTA prepared for reciprocal blast
# * length of each non-redundant sequence
# * pre-clustered gene id
# * each genome that is redundancy-removed
# * gene id information: a tab delimited table, first column as short id generated by software, second colums as description line of original fasta
#
# In previous versions, program would BLAST the concatenated FASTA against each dereplicated genome sequentially, as direct all-vs-all BLAST using concatenated FASTA would be too memory intensive to run (1~ G FASTA direct all-vs-all BLAST cost roughly 120 GB memory using `-mt_mode 1` with 36 threads). <br>
#
# As tested, BLAST the concatenated FASTA against each genome (`-mt_mode 1` and 36 threads) could also be very time consuming:
# * 500 <i>Listeria monocytogenes</i> costs > 7 hours.<br>
# * 1150 <i>E. coli</i> costs > 2.7 days.<br>
#
# However, when running the program for phylogneticlly close genmoes, there would be a high duplication level in the concatenated FASTA.<br>
#
# As tested, the size of concatenated FASTA could be significantly reduced after dereplication:
# * 500 <i>Listeria monocytogenes</i> before dereplication -> ~1.33GB, after -> ~187MB,
# * 1150 <i>E. coli</i> before dereplication -> ~5.2GB, after -> ~986MB
#
# Besides dereplication on concatenated FASTA, this version would also use this dereplicated concatenaion to re-generate each genome without overall redundancy (non-redundant genome). Which would significantly reduce task labor.<br>
#
# As tested, the BLAST time usage after dereplication could be significantly reduced:
# * 500 <i>Listeria monocytogenes</i> before dereplication -> ~7 hours, after -> ~22 mins
# * 1150 <i>E. coli</i> before dereplication -> ~2.7 days, after -> less than 3.5 hours

# %% [markdown]
# ## define functions

# %%
def save_nr_each(in_genome_lst, fasta_dict, op):
    
    for nr_genome in in_genome_lst:
        saver = []
        
        for id_ in nr_genome: 
            saver.append(fasta_dict[id_])
        
        SeqIO.write(saver, 
                    os.path.join(op,
                                 nr_genome[0].partition("-")[0] + '.fasta'
                                ), 
                    'fasta'
                   )

# %% [markdown]
# ## Set path
# * Set variable `dir_dereped_fasta_path` as path to directory dereplicated FASTAs file made in Step 2.
# * Set variable `cated_dereped_fasta_path` as path to dereplicated concatenated FASTA file.
# * Set variable `nr_genomes_pth` as path to directory of each non-redundant genome file.
# * Set variable `len_infor_path` as path to file of sequence length information.
# * Set variable `pre_cluster_path` as path to file pre-clustered gene id.
# * Set variable `id_info_path` as path information gene id.
# * Set variable `process_number` as thread number.<br>

# %%
# path to concatenated fasta made in Step 3
dir_dereped_fasta_path = 'test_op/S2_op_dereped/'
# path to the dereplicated concatenated fasta
cated_dereped_fasta_path = 'test_op/S3_op_dereped_cated.fasta'
# path to the dereplicated of non-redundant genomes
nr_genomes_pth = 'test_op/S3_op_nr_genomes/'
# path to save sequence lenght of each sequence
len_infor_path = 'test_op/S3_op_seq_len.txt'
# path to save pre-cluster
pre_cluster_path = 'test_op/S3_op_pre_cluster.txt'
# path to save gene id info
id_info_path = 'test_op/S3_op_id_info.txt'
# how many jobs to parallel
process_number = 56

# %%
print(time.asctime())

length_info = open(len_infor_path, 'w')

pre_cluster = defaultdict(list)
each_d = defaultdict(list)

dereped_cated_dict = {}

dereped_cated = []

id_info = open(id_info_path, 'w')
# derep of all ----
for f_naam in os.listdir(dir_dereped_fasta_path):
    a_fasta = SeqIO.parse(os.path.join(dir_dereped_fasta_path, 
                                       f_naam),
                          'fasta')
    for rec in a_fasta:
        
        id_info.write(rec.id + '\t' + rec.description.partition(" ")[2] + '\n')
        SEQ = str(rec.seq)

        if SEQ in pre_cluster.keys():# if already presence
            pre_cluster[SEQ].append(rec.id) # must after if

        else:
            length_info.write(rec.id 
                              + '\t' 
                              +  str(len(SEQ)) 
                              + '\n')
            pre_cluster[SEQ].append(rec.id)

            dereped_cated.append(rec)
            dereped_cated_dict[rec.id] = rec
            
            each_d[rec.id.partition("-")[0]].append(rec.id)
        
length_info.close()
id_info.close()

# save pre cluster ----
pre_cluster_file = open(pre_cluster_path, 'w')

for _100_clus in pre_cluster.values():
    LEN = len(_100_clus)
    LEN_1 = LEN - 1
    for ele in range(LEN):
        if ele == LEN_1:
            pre_cluster_file.write(_100_clus[ele] + '\n')
        else:
            pre_cluster_file.write(_100_clus[ele] + '\t')

pre_cluster_file.close()

# save dereped_cated ----
SeqIO.write(dereped_cated, 
            cated_dereped_fasta_path,
            'fasta')

# nr genomes ----
if os.path.exists(nr_genomes_pth):
    pass
else:
    os.mkdir(nr_genomes_pth)
    
if __name__ == "__main__":
                                       
        
    mission_lst = list(each_d.values())
    
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    jobs = []
    
    for sub_mission_lst in mission_lst:
        
        p = Process(target = save_nr_each,
                    args = (sub_mission_lst,
                            dereped_cated_dict,
                            nr_genomes_pth
                           )
                   )
            
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
print(time.asctime())
# Out:
# Sat Jul 12 17:27:58 2025
# Sat Jul 12 17:28:04 2025

# %% [markdown]
# # Step 4 Reciprocal Blast

# %% [markdown]
# Step 4 will carry out the Reciprocal Blast using NCBI Blast. You can get it from [NCBI official](https://ftp.ncbi.nlm.nih.gov/blast/executables/blast+/LATEST/)
#
# The pipeline will assist you to:<br>
# 1. Create databases for each of all dereplicated genomes using `makeblastdb`.
# 2. Using `blastn` or `blastp` to align the `dereplicated concatenated FASTA` against each of the database just made and get tabular output.
#
# ## makeblastdb
# To create database to BLAST, users should provide **path to directory where all non-redundant FASTA made in Step 3 is**, and a **path to output directory where BLAST database is to store**.<br>

# %% [markdown]
# ### define functions

# %%
def make_a_db(in_abs_pth, 
              db_dir_abs_pth, 
              dbtype,
              makeblastdb_bin):
#     if db folder exist
    strain_naam = os.path.basename(in_abs_pth)
    strain_naam = os.path.splitext(strain_naam)[0]
    
    save_dest = os.path.join(db_dir_abs_pth, strain_naam)
    
    if os.path.exists(save_dest):
        pass
    else:
        os.mkdir(save_dest)
        
    save_naam = os.path.join(save_dest, strain_naam)
        
    subprocess.run([makeblastdb_bin, 
                    "-dbtype", dbtype, 
                    "-in", in_abs_pth,
                    "-out", save_naam,
                    "-parse_seqids"
                   ],
                   stdout = subprocess.DEVNULL
                  )
    
def make_dbs(in_abs_pth_lst,
             db_dir_abs_pth_,
             dbtype_,
             makeblastdb_bin_):
    for s in in_abs_pth_lst:
        make_a_db(s, 
                  db_dir_abs_pth_, 
                  dbtype_,
                  makeblastdb_bin_)

# %% [markdown]
# ### Set path
# * Set variable `nr_genomes_pth` as path to directory of each non-redundant genome file.
# * Set variable `blastdb_dir_path` as path to directory to store generated databases.
# * Set variable `process_number` thread number.
# * Set variable `dbt` as the tpye of database to make.
# * Set variable `mbdb` to the path to makeblastdb command.
#
# Then run the codes below [makeblastdb](###makeblastdb)

# %% [markdown]
# In case you have installed your blast but not exported to `$PATH`, you can simply input `whereis blastn` or `whereis makeblastdb` to get the full path to your blast binary file.<br>

# %%
! whereis makeblastdb
# Out:
# makeblastdb: /opt/conda/envs/qiime2-amplicon-2024.5/bin/makeblastdb

# %%
# set your own
# directory path of output
nr_genomes_pth = 'test_op/S3_op_nr_genomes/'
# directory path of blastdb
blastdb_dir_path = 'test_op/S4_op_dbs'
# how many jobs to parallel
process_number = 56
# set dbtype: nucl or prot
dbt = 'nucl'
# set path to makblastdb bin file
mbdb = 'makeblastdb'

# %% [markdown]
# ### makeblastdb

# %%
print(time.asctime())

if __name__ == "__main__":
    
    # mkdir or not
    if os.path.exists(blastdb_dir_path):
        pass
    else:
        os.mkdir(blastdb_dir_path)
    
    mission_lst = os.listdir(nr_genomes_pth)
    
    mission_lst = [os.path.join(nr_genomes_pth, x) for x in mission_lst]
    
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    # mp
    jobs = []
    
    for sub_mission_lst in mission_lst:
    
        p = Process(target = make_dbs,
                    args = (sub_mission_lst, 
                            blastdb_dir_path, 
                            dbt,
                            mbdb
                           )
                   )
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
        
print(time.asctime())
# Out:
# Mon Mar  3 02:23:16 2025
# Mon Mar  3 02:23:28 2025

# %% [markdown]
# ## Reciprocal Blast

# %% [markdown]
# To perform reciprocal BLAST, users should provide **path to dereplicated concatenated FASTA producd by step 3**, **path to directory where databases made by `makeblastdb`**, and a **path to output directory where BLAST tabular output** is to store.<br>
#
# The reason to BLAST against each database sequentially rather than directly using an all-vs-all approach is to reduce computational overhead. This can be very useful if the task involves many genomes. For example, if you have 1000 dereplicated genomes to analyze, the total size of concatenated FASTA may reach 5-10 GB. A multi-threaded BLAST job using the `-mt_mode 1` by all-vs-all style could be too memory-intensive to run for such a large dataset.
#
# In addition, sequentially running BLAST will produce one tabular output per database. This will be a better adaptation for the job parallelization of finding reciprocal best hits in later steps, which will apply the hash binning method.
#
# Since version `0.1` onward, program allow users to choose recoprocal BLAST executed under memory efficient mode or not. Under memory efficient mode, the real-time memory usage will be much lower but **much more** time consuming.
#
# Since version `0.2.1` onward, users are allowed to set customized blast output format for other analysis requirement. If a follow up OthoSLC analysis is needed, leave the parameter as unspecified as default - `"6 qseqid sseqid score"` so that follow up command could parse the blast output.

# %% [markdown]
# ### define function

# %%
def RBB(cmd_lst_,
        db_pth, # alread abs
        blast_res_dir, # already abs
       ):
    strain_naam = db_pth.split('/')[-1]
    
    db_name = os.path.join(db_pth, strain_naam)
    save_dest = os.path.join(blast_res_dir, strain_naam + '.tab')
    
    cmd_lst_l = copy.deepcopy(cmd_lst_)

    cmd_lst_l.extend([
        "-db", db_name,
        "-out", save_dest
    ])
    
    subprocess.run(cmd_lst_l)
    
def RBB_high(cmd_lst_,
             db_pth_lst, # alread abs
             blast_res_dir_, # already abs
             pro_id_, 
             s_t_d,
             st_lock_,
             available_threads):
    for db in db_pth_lst:
        st_lock_.acquire()
        if sum(s_t_d.values()) >= available_threads:
            useable_th = s_t_d[pro_id_]
#             print(str(pro_id_) + ' uses ' + str(useable_th))
        else:
            s_t_d[pro_id_] = s_t_d[pro_id_] + (available_threads - sum(s_t_d.values()
                                                                       )
                                                )
            useable_th = s_t_d[pro_id_]
#             print(str(pro_id_) + ' uses ' + str(useable_th))
        st_lock_.release()
    
        cmd_lst_l = copy.deepcopy(cmd_lst_)
    
        cmd_lst_l.extend(["-num_threads", str(useable_th)])
        RBB(
            cmd_lst_l,
            db, # alread abs
            blast_res_dir_, # already abs
        )

    st_lock_.acquire()
    s_t_d[pro_id_] = 0
#     print(str(pro_id_) + ' finished')
    st_lock_.release()

# %% [markdown]
# ### Set path
# * Set variable `cated_dereped_fasta_path` as path to dereplicated concatenated FASTA file.
# * Set variable `blastdb_dir_path` as path to directory to store generated databases.
# * Set variable `process_number` thread number.
# * Set variable `E_value` as e value parameter during BLAST.
# * Set variable `blast_bin_` to the path to BLAST command.
# * Set variable `blast_op_dir` to the path of directory to save BLAST output.
# * Set variable `mem_eff` as Ture or False to run under memory efficient mode or not.
# * Set variable `outfmt` to specify output format if other format needed.
#
# Then run the codes below [BLAST](###BLAST)

# %%
! whereis blastn
# Out:
# blastn: /opt/conda/envs/qiime2-amplicon-2024.5/bin/blastn

# %%
# set your own
# path to concatenated fasta
cated_dereped_fasta_path = 'test_op/S3_op_dereped_cated.fasta'
# directory path of blastdb
blastdb_dir_path = 'test_op/S4_op_dbs/'
# how many jobs to parallel
process_number = 56
# set e_value
E_value = 1e-5
# set strand direction
strand = 'plus'
# set path to blast bin file`
blast_bin_ = 'blastn'
# set blast output directory
blast_op_dir = 'test_op/S4_op_blast_op'
# memory efficient mode 
mem_eff_mode = False
# blast output format
outfmt = str("6 qseqid sseqid pident score evalue")
# blastp task, select from <'blastp' 'blastp-fast' 'blastp-short'>, unspecified means `'blastp'` as default
blastp_task = ''
# blastp task <blastn' 'blastn-short' 'dc-megablast' 'megablast' 'rmblastn' > , unspecified means `'megablast'` as default
blastn_task = ''

# %% [markdown]
# ### BLAST

# %%
print(time.asctime())
# mkdir or not
if os.path.exists(blast_op_dir):
    pass
else:
    os.mkdir(blast_op_dir)
    
mission_lst = os.listdir(blastdb_dir_path)
mission_lst = [os.path.join(blastdb_dir_path, x) for x in mission_lst]
size = [sum([os.path.getsize(os.path.join(i, j)) for j in os.listdir(i)]) for i in mission_lst]
sorted_mission_lst = [x for _, x in sorted(zip(size, mission_lst))]

cmd_lst = [blast_bin_, 
            "-query", cated_dereped_fasta_path,
            # "-db", db_name,
            # "-out", save_dest,
            "-evalue", str(E_value),
            "-strand", strand,
            "-max_hsps", "1",
            # "-dust", "no",
            "-outfmt", outfmt,
            "-mt_mode", "1"
            # "-num_threads", str(t_num)
            ]

if 'blastn' in blast_bin_:
    cmd_lst.extend(["-dust", "no"])
    if blastn_task == '':
        pass
    else:
        cmd_lst.extend(["-task", blastn_task])
elif 'blastp' in blast_bin_ and blastp_task == "":
    if blastp_task == '':
        pass
    else:
        cmd_lst.extend(["-task", blastp_task])

if mem_eff_mode:
    blast_low = RBB

    cmd_lst.extend(["-num_threads", str(process_number)])

    for db in sorted_mission_lst:
        
        blast_low(cmd_lst,
                  db, 
                  blast_op_dir
                  )
        
else:
    mission_lst = mission_spliter(sorted_mission_lst, 
                                  process_number
                                 )
    
    blast_high = RBB_high

    if __name__ == "__main__":
        with Manager() as manager:
            smart_threads_d = manager.dict()
            
            st_lock = Lock()
            
            for x in range(len(mission_lst)):
                smart_threads_d[x] = 1
        
            # mp
            jobs = []
    
            pro_id = 0
            for db_lst in mission_lst:

                p = Process(target = blast_high,
                            args = (cmd_lst,
                                    db_lst,
                                    blast_op_dir,
                                    pro_id,
                                    smart_threads_d, 
                                    st_lock,
                                    process_number,
                                   )
                           )
                p.start()
                jobs.append(p)
                
                pro_id += 1


            for z in jobs:
                z.join()

print(time.asctime())
# Out:
# Mon Mar  3 02:23:39 2025
# Mon Mar  3 02:47:30 2025

# %% [markdown]
# # Step 5 query binning

# %% [markdown]
# This is the new feature in since version `0.1`. This step is to apply hash binning to bin all presence of a query into same file to facilitate next step filtering.
#
# <font color="red"><b>Set bin level:</b></font><br>
# According to the amount of genomes to analysze, user should provide binning level, which is to set how many bins should be used. Level $L$ should be interger within range $0 < L \le 9999$, and will generate $L$ bins.
#
# Suggestion is that do not set the bin level too high, especially when less than 200 genomes participated. If such amount of genomes participated analysis, bin level from 10 to 100 should work as most efficient way.
#
# As tested, an analysis of 30 genomes, has 30 BLAST output after step 4.
# * A bin level of 10, takes 7 seconds to finish,
# * a bin level of 100, takes 10 seconds to finish,
# * a bin level of 1000, takes 24 seconds to finish,
#
# <font color="red"><b>When to set a high bin level:</b></font><br>
# Simply speaking, when you have really larger amount of genomes and not enough memory (e.g., more than 1000 genomes and less than 100 GB memory) <br>
#
# For example, if the output of BLAST for 1000 genomes reach 150 GB in size, and if the bin level is set to 10, there will be 10 bins to evenly distribute the data. On average, each bin will contain 1.5 GB of data, which may be too memory-intensive to process in step 5 (where requires approximately 1.5 GB of memory per bin). However, if the number of bins is increased to 1000, the size of each bin will be reduced to between 100-200 MB, it will then facilitate step 6 parallelization.
#
# <font color="red"><b>No lock mode:</b></font><br>
# we provide **no lock mode** in all steps that apply hash binning to speed up the process. We allow users to turn off mutex lock which is to safely write into files when multi-threading. In ours tests, program can generate files without data corruption when multi-threading with no lock (data corruption were rarely observed, the possiblity of data corruption may vary between computation platform).

# %% [markdown]
# ## define functions

# %%
def q_binning(in_f_lst, bin_level, bin_op_dir, no_lock_mode, LOCKS):
    for in_f in in_f_lst:
        f = open(in_f, 'r')

        save_dict = defaultdict(list)

        while True:
            l_ = f.readline()
            if l_ == '':
                break

            l_s = l_.split('\t')
            query = l_s[0]
            subject = l_s[1]
            if query.partition("-")[0] == subject.partition("-")[0]:
                continue

            bin_ = hash(query) % bin_level

            save_dict[bin_].append(l_)
        f.close()
        
        # saving
        for b in save_dict.keys():
            if not no_lock_mode:
                LOCKS[int(b)].acquire()

            f = open(os.path.join(bin_op_dir, str(b) + '.txt'), 'a')

            f.writelines(save_dict[b])

            f.close()
            if not no_lock_mode:
                LOCKS[int(b)].release()

# %% [markdown]
# ## Set path
# * Set variable `blast_op_dir` to the path of directory to save BLAST output.
# * Set variable `process_number` thread number.
# * Set variable `b_level` as how many bins to generate.
# * Set len_infor_path `query_bin_op_dir_` to the path of output directory.
#
# Then run the codes below [Step 5 execution](###Step-6-exeution)

# %%
# set your own
# set blast output directory
blast_op_dir = 'test_op/S4_op_blast_op/'
# how many jobs to parallel
process_number = 56
# set bin level
b_level = 100
# set blast output directory
query_bin_op_dir_ = 'test_op/S5_op'
# set whether turn off lock
no_lock_mode = True

# %% [markdown]
# ## Step 5 execution

# %%
if b_level < 0 or b_level > 9999 or not isinstance(b_level, int):
    print('b_level must be integer within range 0 < L <= 9999')
    sys.exit()
    
# mkdir or not

if os.path.exists(query_bin_op_dir_):
    pass
else:
    os.mkdir(query_bin_op_dir_)
    
print(time.asctime())

if __name__ == "__main__":
    
    mission_lst = os.listdir(blast_op_dir)
    
    mission_lst = [os.path.join(blast_op_dir, x) for x in mission_lst]
    
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    # mp
    locks = [Lock() for i in range(b_level)]
    
    jobs = []
    
    for sub_mission_lst in mission_lst:
    
        p = Process(target = q_binning,
                    args = (sub_mission_lst, 
                            b_level, 
                            query_bin_op_dir_,
                            no_lock_mode,
                            locks
                           )
                   )
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
        
print(time.asctime())
# Out:
# Mon Mar  3 02:52:59 2025
# Mon Mar  3 02:53:02 2025

# %% [markdown]
# # Step 6 Filtering and binning

# %% [markdown]
# This step is to filter the blast output and to apply hash binning, in order to provide best preparation for reciprocal best find.<br>
#
# Step 6 requires **path to directory of query binning output (Step 5)**, **sequence length information, pre-cluster information output by Step 3** as input.
#
# The pipeline will carry out following treatment to BLAST output:
# 1. Paralog removal: <br>
# If query and subject is from same strain, the hit will be skipped, as to remove paralog.
# 2. Length ratio filtering:<br>
# Within a hit, query length $Q$ and subject length $S$, the ratio $v$ of this 2 length
#
# $$v = \frac{Q}{S}$$
#
# should be within a range, according to [L. Salichos et al](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0018755), $r (0 < r \le 1)$ is recommended to be higher than 0.3 which means the shorter sequence should not be shorter than 30% of the longer sequence:
#
# $$r \le v \le \frac{1}{r}$$<br>
#
# If above condition not met, the hit will be removed from analysis.
#
# 3. Non-best-hit removal: <br>
# * Identical sequences are always regarded as best hit.
# * If a query has more than 1 subject hits, only the query-subject pair with highest score will then be kept.
# * if pairs are of same score, the pair whose query and subject are of more similar length will be kept.
# 4. Sorting and binning:<br>
# For every kept hit, its query and subject will be sorted using Python or C++ built in sort algorithm. This is because in a sequential blast output file, only "<b>single direction best hit</b>" can be obtained, its "<b>reciprocal best hit</b>" only exist in other files, which poses difficulty doing "<b>repriprocal finding</b>". <br>
# However, if a query $a$ and its best suject hit $b$, passed filter above, and form $(a, b)$, and in the mean time we sort its rericprocal hit $(b, a)$ from another file into $(a, b)$, then both $(a, b)$ will generate same hash value. This hashed value with last several digits will allow us to bin them into same new file. Therefore, after this binning, "<b>reciprocal finding</b>" will be turned into "<b>duplication finding</b>" within one same file.<br>
#
# <font color="red"><b>Set bin level:</b></font><br>
# According to the amount of genomes to analysze, user should provide binning level, which is to set how many bins should be used. Level $L$ should be interger within range $0 < L \le 9999$, and will generate $L$ bins.
#
# Suggestion is that do not set the bin level too high, especially when less than 200 genomes participated. If such amount of genomes participated analysis, bin level from 10 to 100 should work as most efficient way.
#
# <font color="red"><b>When to set a high bin level:</b></font><br>
# Simply speaking, when you have really larger amount of genomes and not enough memory (e.g., more than 1000 genomes and less than 100 GB memory) <br>
#
# for example, if the output of BLAST for 1000 genomes reach 200 GB in size, and if the bin level is set to 100, there will be 100 bins to evenly distribute the data. On average, each bin will contain 1.7 GB of data, which may be too memory-intensive to process in step 7, where reciprocal find is performed (which requires approximately 1.7 GB of memory per bin). However, if the number of bins is increased to 1000, the size of each bin will be reduced to between 100-200 MB, which then facilitate step 7 parallelization.
#
# <font color="red"><b>Note:</b></font><br>
# This is the one of the most computation and I/O intensive step, use the C++ based binary file to process for better efficiency.

# %%
def filter_n_bin(blast_op_pt_lst, # to avoid redundant copy of  seqlen info, abs pth
                  r,
                  m,
                  weight,
                  bin_level, 
                  bin_op_dir, # already abs
                  seq_len_info,
                  bin_spe, # pre_cluster
                  no_lock_mode,
                  LOCKS):
    for fs in blast_op_pt_lst:
        
        f = open(fs, 'r')
            
        q_s_d = defaultdict(dict)
        
        sspe_m = defaultdict(lambda: defaultdict(list
                                                )
                            )
        
        while True:
            l_ = f.readline()
            if l_ == '':
                break
                
#             l_ = l_.rstrip('\n') '\n' do not affect number  
            l_ = l_.split('\t')
            
            identity = float(l_[2])
            if identity < m:
                continue
            
            query = l_[0]
            subject = l_[1]
            
            # if query.partition("-")[0] == subject.partition("-")[0]: # if self hit - filtered by previous step already
            #     continue
            # else:
            score = int(l_[3])
            
            q_s_d[query][subject] = (score, identity, float(l_[4]))
#                 {q1: {s1: score,
#                       s2: score
#                      },
#                  q2
#                 }
            
            # add all spe
            for a_spe_of_clus in bin_spe[subject]:
                sspe_m[query][a_spe_of_clus].append(subject)
#                     {
#                         q1: {
#                             a1_spe_in_cluster_of_sub: [subject1 id,
#                                                     subject2 id
#                                                    ],
#                             a2_spe_in_cluster_of_sub: [subject3 id,
#                                                     subject4 id
#                                                    ],
#                         },
#                         q2
#                     }
        f.close()
        # how to save
        saver = defaultdict(list)
        
        for qs in q_s_d.keys():
            q_len = seq_len_info[qs]
            
            for sub in q_s_d[qs].keys():
                s_spe = sub.partition("-")[0]
                
                if s_spe in bin_spe[qs]:# if qs pre cluster has that spe
                    continue
                    
                else:
                    best_hit = True
                    
                    same_score = []
                    
                    if len(sspe_m[qs][s_spe]) > 1: #if multiple hit in a spe
                        for id_ in sspe_m[qs][s_spe]:
                            # if sub == id_: # skip self
                            #     continue
                                
                            if q_s_d[qs][sub][0] < q_s_d[qs][id_][0]: # if there is a better hit
                                best_hit = False
                                break
                            elif q_s_d[qs][sub][0] == q_s_d[qs][id_][0]: # same score 
                                same_score.append(id_)
                    
                    if len(same_score) > 0 and best_hit: # need more similar length # print(qs + "<>" + sub)
                        
                        qs_len_diff = abs(q_len - seq_len_info[sub])
                        
                        for id_ in same_score:
                            q_id_len_diff = abs(q_len - seq_len_info[id_])
                            
                            if q_id_len_diff < qs_len_diff:
#                                 print(qs + "< >" + sub + "< >" + id_)
                                best_hit = False
                                break
                                
                    if best_hit:
                        len_ratio = q_len/seq_len_info[sub]
                        
                        c1 = len_ratio <= r
                        c2 = len_ratio >= (1/r)
                        
                        if c1 or c2: # len ratio filter
#                             print(qs + "< >" + sub)
                            continue
                        else:
                            sorting = sorted((qs, sub)) 
                            
                            bin_ = hash(tuple(sorting
                                             )
                                       ) % bin_level

                            a_pair = sorting[0] + '\t' + sorting[1]
                            if weight == 'none':
                                saver[str(bin_)].append(a_pair + '\n')
                            elif weight == 2:
                                saver[str(bin_)].append(a_pair + '\t' + str(-log10(q_s_d[qs][sub][weight]+1)) + '\n')
                            else:
                                saver[str(bin_)].append(a_pair + '\t' + str(q_s_d[qs][sub][weight]) + '\n')
                            
        for b in saver.keys():
            if not no_lock_mode:
                LOCKS[int(b)].acquire()

            f = open(os.path.join(bin_op_dir, b + '.txt'), 'a')

            f.writelines(saver[b])

            f.close()
            
            if not no_lock_mode:
                LOCKS[int(b)].release()

# %% [markdown]
# ## Set path
# * Set variable `process_number` thread number.
# * Set variable `b_level` as how many bins to generate.
# * Set variable `r_` as the limit of length difference ratio.
# * Set variable `blast_op_dir` to the path of directory to save BLAST output.
# * Set variable `len_infor_path` as path to file of sequence length information.
# * Set variable `pre_cluster_path` as path to file pre-clustered gene id.
#
# Then run the codes below [Step 6 execution](###Step-6-execution)

# %%
# set your own
# set blast output directory
qbin_op_dir = 'test_op/S5_op/'
# how many jobs to parallel
process_number = 56
# set bin level
b_level = 100
# set length ratio limit r value 
r_ = 0.8
# set similarity limit 
m_ = 80
# set weight to keep select from <'none', 'pident', 'score', 'evalue'>
weight = 'score'
# set blast output directory
bin_op_dir_ = 'test_op/S6_op'
# path save sequence lenght of each sequence
len_infor_path = 'test_op/S3_op_seq_len.txt'
# path to save pre-cluster
pre_cluster_path = 'test_op/S3_op_pre_cluster.txt'
# set whether turn off lock
no_lock_mode = True

# %% [markdown]
# ## Step 6 execution

# %%
if b_level < 0 or b_level > 9999 or not isinstance(b_level, int):
    print('b_level must be integer within range 0 < L <= 9999')
    sys.exit()

wei = {'score':0,
       'pident': 1,
       'evalue': 2
      }
if weight != 'none':
    weight = wei[weight]

# mkdir or not
if os.path.exists(bin_op_dir_):
    pass
else:
    os.mkdir(bin_op_dir_)

# seq len
seq_len_d = {}
seq_len = open(len_infor_path, 'r')
seq_len_rls = seq_len.readlines()
seq_len.close()

for ros in seq_len_rls:
    l_ = ros.rstrip('\n').split('\t')
    seq_len_d[l_[0]] = float(l_[1])


# bin spe
bin_spe = {}
f = open(pre_cluster_path, 'r')
while True:
    l_ = f.readline()
    if l_ == '':
        break
    
    
    l_ = l_.rstrip('\n').split('\t')
    
    bin_ = l_[0]
    
    bin_spe[bin_] = [x.partition("-")[0] for x in l_]
f.close()

print(time.asctime())

if __name__ == "__main__":
    
    mission_lst = os.listdir(qbin_op_dir)
    mission_lst = [os.path.join(qbin_op_dir, x) for x in mission_lst]
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    # mp
    locks = [Lock() for i in range(b_level)]
    
    jobs = []
    
    for sub_mission_lst in mission_lst:
    
        p = Process(target = filter_n_bin,
                    args = (sub_mission_lst, 
                            r_, 
                            m_,
                            weight,
                            b_level,
                            bin_op_dir_,
                            seq_len_d,
                            bin_spe,
                            no_lock_mode,
                            locks
                           )
                   )
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
        
print(time.asctime())
# Out:
# Thu Mar  6 03:14:53 2025
# Thu Mar  6 03:15:23 2025

# %% [markdown]
# # Step 7 Reciprocal Best find

# %% [markdown]
# This Step is to find reciprocal best hits. In `Step 6`, query-subject pairs had been binned into different files according to their hash value, therefore, pair $(a, b)$ and its reciprocal pair $(b, a)$ (which was sorted into $(a, b)$), will be in the same bin. Thus, a pair found twice in a bin will be reported as a reciprocal best blast pair.
#
# In addition, Step 7 also does hash binning after a reciprocal best hit is comfirmed. Query-subject pairs will be binned by the hash value of query ID, which then put pairs with common elements into same bin to assist faster clustering in next step.
#
# Step 7 requires **path to directory of bins output by Step 6**, and path to output directory.
#
#
# <font color="red"><b>Set bin level:</b></font><br>
# According to the amount of genomes to analysze, user should provide binning level, which is to set how many bins should be used. Level $0 < L \le 9999$, and will generate $L$ bins.
#
# Suggestion is that do not set the bin level too high, especially when less than 200 genomes participated. If such amount of genomes participated analysis, bin level from 10 to 100 should work as most efficient way.
#
# As tested, 30 genomes, if 10 bins generated by Step 7:
# * A bin level of 10, takes 1 seconds to finish,
# * a bin level of 100, takes 2 seconds to finish,
# * a bin level of 1000, takes 7 seconds to finish,
#
# <font color="red"><b>When to set a high bin level:</b></font><br>
# Simply speaking, when you have really larger amount of genomes and not enough memory (e.g., more than 1000 genomes and less than 100 GB memory) <br>
#
# Less bins could make step 7 faster, but step 8 more memory intensive.
#
# <font color="red"><b>Note:</b></font><br>
# This is the one of the most computation and I/O intensive step, use the C++ based binary file to process for better efficiency.

# %% [markdown]
# ## define functions

# %%
def dup_find_mem(in_file_lst, RBB_op_dir, bin_level, no_lock_mode, LOCKS):
    for in_file in in_file_lst:
        naam = os.path.basename(in_file)

        f = open(in_file, 'r')

        rec = set()
        d_bin = defaultdict(list)

        while True:
            l_ = f.readline()
            if l_ == '':
                break

            
            pair = l_.split('\t')
            pair = (pair[0], pair[1])
            if pair in rec:
                hash_res = str(hash(pair[0]) % bin_level
                              )
                d_bin[hash_res].append(l_)
                rec.remove(pair)
            else:
                rec |= set([pair])

        f.close()

        for b in d_bin.keys():
            if not no_lock_mode:
                LOCKS[int(b)].acquire()

            f2 = open(os.path.join(RBB_op_dir, b + '.txt'), 'a')

            f2.writelines(d_bin[b])
            
            f2.close()
            if not no_lock_mode:
                LOCKS[int(b)].release()

# %% [markdown]
# ## Set path
# * Set variable `bin_op_dir_` as path to directory to bins generated by Step 6.
# * Set variable `RBB_op_dir_pth` as path to output directory.
# * Set variable `process_number` thread number.
# * Set variable `b_level` as how many bins to generate
#
# Then run the codes below [Step 7 execution](###Step-7-execution)

# %%
# set blast output directory
bin_op_dir_ = 'test_op/S6_op/'
# set reciprocal best output directory
RBB_op_dir_pth = 'test_op/S7_op'
# how many jobs to parallel
process_number = 56
# set bin level
b_level = 100
# set whether turn off lock
no_lock_mode = True

# %% [markdown]
# ## Step 7 execution

# %%
if b_level < 0 or b_level > 9999 or not isinstance(b_level, int):
    print('b_level must be integer within range 0 < L <= 9999')
    sys.exit()

# mkdir or not
if os.path.exists(RBB_op_dir_pth):
    pass
else:
    os.mkdir(RBB_op_dir_pth)

print(time.asctime())

if __name__ == "__main__":
    
    mission_lst = os.listdir(bin_op_dir_)
    
    mission_lst = [os.path.join(bin_op_dir_, x) for x in mission_lst]
    
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    # mp
    locks = [Lock() for i in range(b_level)
            ]
             
    jobs = []
    
    for sub_mission_lst in mission_lst:
        
        p = Process(target = dup_find_mem,
                    args = (sub_mission_lst,
                            RBB_op_dir_pth,
                            b_level,
                            no_lock_mode,
                            locks
                           )
                   )
            
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
        
print(time.asctime())
# Out:
# Mon Mar  3 03:13:05 2025
# Mon Mar  3 03:13:06 2025

# %% [markdown]
# # Step 8 Clustering (Run only one of SLC or MCL)

# %% [markdown]
# ## Step 8 Option 1: Single Linkage Clustering (SLC)

# %% [markdown]
# This step will carry out single linkage clustering on output from step 7. Users may perform "<b>multi-step-to-final</b>" or "<b>one-step-to-final</b>" clustering by adjusting the `compression_size` parameter. In the output files, each row is a cluster (stopped by "\n") and each gene ID is separated by "\t".
#
# In case that large amount genomes participated analysis, it could be memory intensive to reach final cluster in a single step. The pipeline provide ability to extenuate such pressure by reaching final cluster with multiple steps. For example, if `compression_size` = 5 is provided, program will perform clustering using 5 files at a time and shrink the output file number by a factor of 5.
#
# <font color="red"><b>Note Before Start</b></font><br>
# User <font color="red"><b>must</b></font> specify the path to `pre-cluster file` produced in `Step 3`, when running the <font color="red"><b>LAST step of multi step to final</b></font>, or when running direct <font color="red"><b>one step to final</b></font>.

# %% [markdown]
# ### define functions

# %%
def connect_bin(bin_ind_lst, ind):
    while bin_ind_lst[ind] != ind:
        ind = bin_ind_lst[ind]
    return ind

def ptr_like_merger(in_p_lst, op_dir):
    
    ptr_coll = dict()
    bin_inds_connector = []
    
    to_save_lst = []
    
    const_ind_every = 0
    
    for in_p in in_p_lst[1]:
        f = open(in_p, 'r')
    
        while True:
            l_ = f.readline()

            if l_ == '':
                break

            l_ = set(l_.rstrip('\n').split('\t'))

            ind_to_go = const_ind_every
            to_save_lst.append(l_)
            bin_inds_connector.append(ind_to_go)

            for ele in l_:
                if ele not in ptr_coll.keys():
                    ptr_coll[ele] = ind_to_go

                else:
                    its_lowest_bin_ind = connect_bin(bin_inds_connector, 
                                                     ptr_coll[ele]
                                                    )

                    if its_lowest_bin_ind == ind_to_go:
                        continue

                    if its_lowest_bin_ind > ind_to_go:
                        its_lowest_bin_ind, ind_to_go = ind_to_go, its_lowest_bin_ind

                    to_save_lst[its_lowest_bin_ind] |= to_save_lst[ind_to_go]
                    to_save_lst[ind_to_go] = None

                    bin_inds_connector[ind_to_go] = its_lowest_bin_ind
                    ind_to_go = its_lowest_bin_ind


            const_ind_every += 1

        f.close()
        
    f2 = open(os.path.join(op_dir, str(in_p_lst[0]) + '.txt'), 'w')
    for i in to_save_lst:
        if i:
            i = tuple(i)
            Len = len(i)
            for j in list(range(Len)):
                if j == Len - 1: 
                    f2.write(i[j] + '\n')
                else:
                    f2.write(i[j] + '\t')
        else:
            pass
    f2.close()
                
def files_clustering_s(in_p_lst_lst, op_dir_):
    
    for inp_lst in in_p_lst_lst:
        ptr_like_merger(inp_lst, op_dir_)
        
def SLC(ip, op, proc_num, c_s, pre_clus_pth = ''):
    if os.path.exists(op):
        pass
    else:
        os.mkdir(op)

    print(time.asctime())

    if __name__ == "__main__":

        mission_lst = os.listdir(ip)

        if c_s > len(mission_lst):
            print('Error: Compression size can only be smaller than ' + str(len(mission_lst)))
        else:

            mission_lst = [os.path.join(ip, x) for x in mission_lst]
            
            if pre_clus_pth != '':
                mission_lst.append(pre_clus_pth)
            
            per = len(mission_lst)//c_s

            mission_lst = mission_spliter(mission_lst, 
                                          per
                                         )

            x = 0
            mission_lst_ = []
            for i in mission_lst:
                mission_lst_.append([x, i])
                x += 1

            if len(mission_lst_) < proc_num:
                proc_num = len(mission_lst_)


            mission_lst_ = mission_spliter(mission_lst_, 
                                           proc_num
                                          )
            # mp
            jobs = []
            

            for sub_mission_lst in mission_lst_:

                p = Process(target = files_clustering_s,
                            args = (sub_mission_lst,
                                    op
                                   )
                           )
                p.start()
                jobs.append(p)


            for z in jobs:
                z.join()

        print(time.asctime())

# %% [markdown]
# ### Round 1 set path
# * Set variable `RBB_op_dir_pth` as path to output directory.
# * Set variable `SLC_inter_op_dir_pth` as path to output directory.
# * Set variable `process_number` thread number.
# * Set variable `compression_size` as how many files to cluster into one file.
# * Set variable `pre_cluster_path` as path to file pre-clustered gene id.

# %%
# set reciprocal best output directory
RBB_op_dir_pth = 'test_op/S7_op/'
# set path to directory of clustering output
SLC_inter_op_dir_pth = 'test_op/SLC_1/'
# how many jobs to parallel
process_number = 56
# Compression size
compression_size = 1

# %% [markdown]
# Then run the codes below.

# %%
SLC(RBB_op_dir_pth, SLC_inter_op_dir_pth, process_number, compression_size)
# Out:
# Sun Mar  2 12:20:13 2025
# Sun Mar  2 12:20:14 2025

# %% [markdown]
# ### Round2 set path
# * Set variable `ip_dir_pth` as path to output directory of last round clustering.
# * Set variable `SLC_inter_op_dir_pth` as path to output directory.
# * Set variable `process_number` thread number.
# * Set variable `compression_size` as how many files to cluster into one file.

# %%
# set path to last step clustering output directory
ip_dir_pth = 'test_op/SLC_1/'
# set path to directory of clustering output
SLC_inter_op_dir_pth = 'test_op/SLC_2/'
# how many jobs to parallel
process_number = 56
# Compression size
compression_size = 2

# %% [markdown]
# Then run the codes below.

# %%
SLC(ip_dir_pth, SLC_inter_op_dir_pth, process_number, compression_size)
# Out:
# Sun Mar  2 12:20:14 2025
# Sun Mar  2 12:20:14 2025

# %% [markdown]
# ### Final round set path
# * Set variable `ip_dir_pth` as path to output directory of last round clustering.
# * Set variable `SLC_inter_op_dir_pth` as path to output directory.
# * Set variable `process_number` thread number.
# * Set variable `compression_size` as how many files to cluster into one file.
# * Set variable `pre_cluster_path` path to pre-clustered id file made in **step 3**.

# %%
# set path to last step clustering output directory
ip_dir_pth = 'test_op/SLC_2/'
# set path to final lustering output
SLC_inter_op_dir_pth = 'test_op/Final_cluster/'
# how many jobs to parallel
process_number = 56
# Compression size
compression_size = len(os.listdir(ip_dir_pth))
# path to pre-cluster
pre_cluster_path = 'test_op/S3_op_pre_cluster.txt'

# %% [markdown]
# Then run the codes below.

# %%
SLC(ip_dir_pth, SLC_inter_op_dir_pth, process_number, compression_size, pre_cluster_path)
# Out:
# Sun Mar  2 12:20:15 2025
# Sun Mar  2 12:20:15 2025

# %% [markdown]
# ## Step 8 Option 2: Markov Clustering (MCL)

# %%
# set reciprocal best output directory
RBB_op_dir_pth = 'test_op/S7_op'
# path to pre-cluster
pre_cluster_path = 'test_op/S3_op_pre_cluster.txt'
# path to mcl-cluster result
mcl_cluster_path = 'test_op/Final_cluster/0.txt'
# MCL inflation
MCL_inflation = "1.5"
# set path to final lustering output
Final_cluster_dir_pth = 'test_op/Final_cluster/'

# %%
print(time.asctime())

# MCL prep ----
if not os.path.exists(mcl_cluster_path):
    os.mkdir(mcl_cluster_path)


if os.path.exists(Final_cluster_dir_pth):
    pass
else:
    os.mkdir(Final_cluster_dir_pth)

# read pre cluster
f = open(pre_cluster_path, 'r')
rls = f.readlines()
f.close()

pre_cluster = {}
for c in rls:
    c = c.rstrip('\n').split('\t')
    pre_cluster[c[0]] = set(c)

# walk MCL output
mcl_cluster = {}
clustered_in_MCL = []
f = open(mcl_cluster_path, 'r')
while True:
    l_ = f.readline()
    if l_ == '':
        break
        
    c = l_.rstrip('\n').split('\t')
    c_set = set(c)

    for gene in c:
        clustered_in_MCL.append(gene)
        c_set |= pre_cluster[gene]
    mcl_cluster[c[0]] = deepcopy(c_set)
        
f.close()

un_clustered_in_MCL = set(list(pre_cluster.keys())) - set(clustered_in_MCL)
final_cluster = deepcopy(mcl_cluster)
for c_id in un_clustered_in_MCL:
    final_cluster[c_id] = pre_cluster[c_id]

f2 = open(os.path.join(Final_cluster_dir_pth, '0.txt'), 'w')
for i in final_cluster:
    
    i = tuple(final_cluster[i])
    Len = len(i)
    for j in list(range(Len)):
        if j == Len - 1: 
            f2.write(i[j] + '\n')
        else:
            f2.write(i[j] + '\t')
            
f2.close()

print(time.asctime())
# Out:
# Fri Jul 18 01:34:39 2025
# Fri Jul 18 01:34:39 2025

# %% [markdown]
# # Step 9 Write clusters into FASTA
# In Step 9, program will help user to generate FASTA file for each cluster. By providing the final one cluster file generated by Step 8 as input, program produces 3 types of clusters into 3 directories separately.<br>
#
# Noteably, those genomes
# * depreplicated in **Step 2**,
# * not removed because of too low genome size
# * participated processes up to this step,
#
# are used to separate 3 types of clusters.<br>
#
# 1. In drectory `accessory_cluster`(a cluster not shared by all genomes), FASTA files of clusters, which **do not have genes from all genomes** participated analysis, will be output in this drectory. For example, there are 100 genomes in analysis, a cluster with less than 100 genes will have its FASTA output here. Also, if a cluster has >= 100 genes, but all these genes are from less than 100 genomes, its FASTA will be in this directory.
# 2. In drectory `strict_core`, each cluster has **exactly 1 gene from every genome** to analyze. Such clusters will have their FASTA files here.
# 3. In drectory `surplus_core`, each cluster has **at least 1 gene from every genome** to analyze, and **some genomes has more than 1 genes** in this cluster. Such clusters will have their FASTA files here.
#
# This step also requires the concatenated FASTA made in Step 3 as input.

# %%
def write_a_cluster(a_cluster_of_genes, 
                    total_amount, 
                    which_to_write, 
                    op_path,
                    fasta_dict,
                    id_cluster_d,
                    id_info_d
                    ):
    spe_count = len(set([x.partition("-")[0] for x in a_cluster_of_genes]))
    
    if spe_count < total_amount:
        if which_to_write["accessory_cluster"]:
            file_naam = os.path.join(op_path, 'accessory_cluster/' 
                                     + a_cluster_of_genes[0]
                                     + '.fasta'
                                    )
        else:
            return
    else:
        if len(a_cluster_of_genes) == total_amount:
            if which_to_write["strict_core"]:
                file_naam = os.path.join(op_path, 'strict_core/' 
                                         + a_cluster_of_genes[0] 
                                         + '.fasta'
                                        )
            else:
                return
        else:
            if which_to_write["surplus_core"]:
                file_naam = os.path.join(op_path, 'surplus_core/' 
                                         + a_cluster_of_genes[0] 
                                         + '.fasta'
                                        )
            else:
                return
    
    to_save = []
    for  recs in a_cluster_of_genes:
        to_save.append(SeqRecord(id = recs, 
                                 description = id_info_d[recs],
                                 seq = fasta_dict[id_cluster_d[recs]].seq
                                )
                      )
        
    SeqIO.write(to_save, 
                file_naam, 
                'fasta')

def write_cluster_s(lst_of_a_clusters, 
                    total_amount_, 
                    which_to_write_, 
                    op_path_, 
                    fasta_dict_,
                    id_cluster_d_,
                    id_info_d_):
    
    for a_cl in lst_of_a_clusters:
        write_a_cluster(a_cl, 
                        total_amount_,
                        which_to_write_,
                        op_path_,
                        fasta_dict_,
                        id_cluster_d_,
                        id_info_d_)

# %% [markdown]
# ## Set path
# * Set variable `final_cluster_path` as path to the final cluster file made by Step 8.
# * Set variable `output_path` as path to output directory.
# * Set variable `process_number` thread number.
# * Set variable `cluster_type` select from `accessory/strict/surplus`, separate by comma (`,`).
#
#
# * Set variable `dereped_fasta_path` as path to globally dereplicated FASTAs made in Step 3.
# * Set variable `id_info_path` path to save gene id info made in Step3.
# * Set variable `pre_cluster_path` path to pre-clustered gene id info made in Step3.

# %%
# set path to the final cluster file made by Step 7
final_cluster_path = 'test_op/SLC_final/0.txt'
# set path to output directory
output_path = 'test_op/S9_write_fasta'
# how many jobs to parallel
process_number = 16

# select at least 1 from `accessory/strict/surplus`, separate by comma (`,`), 
# specifying types of clusters to write
cluster_type = 'accessory,strict,surplus'

# set path to concatenated dereped FASTA file made in Step 3.
dereped_fasta_path = 'test_op/S3_op_dereped_cated.fasta'
# set path to save gene id info made in Step3
id_info_path = 'test_op/S3_op_id_info.txt'
# set path to save pre-cluster
pre_cluster_path = 'test_op/S3_op_pre_cluster.txt'

# %% [markdown]
# * Set variable `total_amount` of the how many genomes participated analysis.

# %%
# directory path of output
print(len(os.listdir(dir_dereped_fasta_path)
         )
     )

# %%
# how many genomes participated analysis.
total_amount = len(os.listdir(dir_dereped_fasta_path)
                      )

# %% [markdown]
# ## run the codes below get final FASTA files

# %%
print(time.asctime())
# mkdir or not
if os.path.exists(output_path):
    pass
else:
    os.mkdir(output_path)
    

# readin ----
cated_fasta = SeqIO.to_dict(SeqIO.parse(dereped_fasta_path, 
                                        'fasta')
                           )

# id: cluster_id dict of 100% same seqs ----
f = open(pre_cluster_path, 'r')
id_cluster = f.readlines()
f.close()

id_cluster_dict = {}
for cls in id_cluster:
    l_ = cls.rstrip('\n').split('\t')
    
    for a_id in l_:
        id_cluster_dict[a_id] = l_[0]

# id: sqe_info ----
f = open(id_info_path, 'r')
id_info = f.readlines()
f.close()

id_info_dict = {}
for pair in id_info:
    l_ = pair.rstrip('\n').split('\t')
    id_info_dict[l_[0]] = l_[1]
        
# which to write
types_to_write = {
    'accessory_cluster': False,
    'strict_core': False,
    'surplus_core': False
} 
for x in cluster_type.split(','):
    if x == 'accessory':
        types_to_write['accessory_cluster'] = True
        if os.path.exists(os.path.join(output_path, 'accessory_cluster')):
            pass
        else:
            os.mkdir(os.path.join(output_path, 'accessory_cluster'))
    
    elif x == 'strict':
        types_to_write['strict_core'] = True
        if os.path.exists(os.path.join(output_path, 'strict_core')):
            pass
        else:
            os.mkdir(os.path.join(output_path, 'strict_core'))
            
    elif x == 'surplus':
        types_to_write['surplus_core'] = True
        if os.path.exists(os.path.join(output_path, 'surplus_core')):
            pass
        else:
            os.mkdir(os.path.join(output_path, 'surplus_core'))
        
    
# read cluster
f = open(final_cluster_path, 'r')
CLUSTERS = f.readlines()
f.close()

if __name__ == "__main__":
    
    mission_lst = [x.rstrip('\n').split('\t') for x in CLUSTERS]
    
    mission_lst = mission_spliter(mission_lst, 
                                  process_number
                                 )
    
    # mp
             
    jobs = []
    
    for sub_mission_lst in mission_lst:
        
        p = Process(target = write_cluster_s,
                    args = (sub_mission_lst,
                            total_amount,
                            types_to_write,
                            output_path,
                            cated_fasta,
                            id_cluster_dict,
                            id_info_dict
                           )
                   )
            
        p.start()
        jobs.append(p)


    for z in jobs:
        z.join()
        
print(time.asctime())
